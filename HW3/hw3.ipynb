# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from pandas.io.json import json_normalize
import json
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.

def load_df(csv_path='../input/ga-customer-revenue-prediction/train.csv', nrows=None):
    JSON_COLUMNS = ['device', 'geoNetwork', 'totals', 'trafficSource']
    
    df = pd.read_csv(csv_path, 
                     converters={column: json.loads for column in JSON_COLUMNS}, 
                     dtype={'fullVisitorId': 'str'}, # Important!!
                     nrows=nrows)
    
    for column in JSON_COLUMNS:
        column_as_df = json_normalize(df[column])
        column_as_df.columns = [f"{column}.{subcolumn}" for subcolumn in column_as_df.columns]
        df = df.drop(column, axis=1).merge(column_as_df, right_index=True, left_index=True)
    print(f"Loaded {os.path.basename(csv_path)}. Shape: {df.shape}")
    return df
# Out:
# ['kernel-for-data', 'customer-revenue-prediction', 'ga-customer-revenue-prediction']

# %%
# X_train = load_df()
# X_test = load_df("../input/ga-customer-revenue-prediction/test.csv")
# X_train.to_csv("train-flat.csv", index=False)
# X_test.to_csv("test-flat.csv", index=False)

# %%
X_train = pd.read_csv("../input/kernel-for-data/train-flat.csv", low_memory = False)

# %%
X_test = pd.read_csv("../input/kernel-for-data/test-flat.csv", low_memory = False)

# %% [markdown]
# Here, we are checking if the unique values in the columns including Nan are greater than 1 or not. If not, the column has only Nan in it and thus we're dropping those columns.

# %%
columns = [col for col in X_train.columns if X_train[col].nunique() > 1]
print(columns)
X_train = X_train[columns]
# Out:
# ['channelGrouping', 'date', 'fullVisitorId', 'sessionId', 'visitId', 'visitNumber', 'visitStartTime', 'device.browser', 'device.deviceCategory', 'device.isMobile', 'device.operatingSystem', 'geoNetwork.city', 'geoNetwork.continent', 'geoNetwork.country', 'geoNetwork.metro', 'geoNetwork.networkDomain', 'geoNetwork.region', 'geoNetwork.subContinent', 'totals.hits', 'totals.pageviews', 'totals.transactionRevenue', 'trafficSource.adContent', 'trafficSource.adwordsClickInfo.adNetworkType', 'trafficSource.adwordsClickInfo.gclId', 'trafficSource.adwordsClickInfo.page', 'trafficSource.adwordsClickInfo.slot', 'trafficSource.campaign', 'trafficSource.keyword', 'trafficSource.medium', 'trafficSource.referralPath', 'trafficSource.source']

# %%
columns.remove('totals.transactionRevenue')

# %%
X_test = X_test[columns]

# %% [markdown]
# COnverting the date from string to pandas date format.

# %%
X_train['date'] = pd.to_datetime(X_train['date'].apply(lambda x: str(x)[:4] + '-' + str(x)[4:6] + '-' + str(x)[6:]))
X_test['date'] = pd.to_datetime(X_test['date'].apply(lambda x: str(x)[:4] + '-' + str(x)[4:6] + '-' + str(x)[6:]))

# %% [markdown]
# Adding new features like day,month,year,week of the year

# %%
X_train['day'] = X_train.date.dt.dayofweek
X_train['month'] = X_train.date.dt.month
X_train['year'] = X_train.date.dt.year
X_train['weekOfTheYear'] = X_train.date.dt.weekofyear

X_test['day'] = X_test.date.dt.dayofweek
X_test['month'] = X_test.date.dt.month
X_test['year'] = X_test.date.dt.year
X_test['weekOfTheYear'] = X_test.date.dt.weekofyear

# %%
percent = (100 * X_train.isnull().sum() / X_train.shape[0]).sort_values(ascending=False)
print(percent)
# Out:
# trafficSource.adContent                         98.788694
# totals.transactionRevenue                       98.725728
# trafficSource.adwordsClickInfo.slot             97.625195
# trafficSource.adwordsClickInfo.page             97.625195
# trafficSource.adwordsClickInfo.adNetworkType    97.625195
# trafficSource.adwordsClickInfo.gclId            97.614018
# trafficSource.referralPath                      63.377425
# trafficSource.keyword                           55.655102
# totals.pageviews                                 0.011066
# device.operatingSystem                           0.000000
# device.isMobile                                  0.000000
# device.deviceCategory                            0.000000
# device.browser                                   0.000000
# visitStartTime                                   0.000000
# weekOfTheYear                                    0.000000
# geoNetwork.continent                             0.000000
# visitNumber                                      0.000000
# visitId                                          0.000000
# sessionId                                        0.000000
# fullVisitorId                                    0.000000
# date                                             0.000000
# geoNetwork.city                                  0.000000
# geoNetwork.subContinent                          0.000000
# geoNetwork.country                               0.000000
# geoNetwork.metro                                 0.000000
# geoNetwork.networkDomain                         0.000000
# geoNetwork.region                                0.000000
# year                                             0.000000
# totals.hits                                      0.000000
# trafficSource.campaign                           0.000000
# trafficSource.medium                             0.000000
# trafficSource.source                             0.000000
# day                                              0.000000
# month                                            0.000000
# channelGrouping                                  0.000000
# dtype: float64

# %%
percent = (100 * X_test.isnull().sum() / X_test.shape[0]).sort_values(ascending=False)
percent
# Out:
# trafficSource.adContent                         93.315264
# trafficSource.adwordsClickInfo.page             93.312406
# trafficSource.adwordsClickInfo.slot             93.312406
# trafficSource.adwordsClickInfo.adNetworkType    93.312406
# trafficSource.adwordsClickInfo.gclId            93.306441
# trafficSource.referralPath                      70.755850
# trafficSource.keyword                           48.594479
# totals.pageviews                                 0.017274
# device.operatingSystem                           0.000000
# device.isMobile                                  0.000000
# device.deviceCategory                            0.000000
# device.browser                                   0.000000
# visitStartTime                                   0.000000
# weekOfTheYear                                    0.000000
# geoNetwork.continent                             0.000000
# visitNumber                                      0.000000
# visitId                                          0.000000
# sessionId                                        0.000000
# fullVisitorId                                    0.000000
# date                                             0.000000
# geoNetwork.city                                  0.000000
# geoNetwork.region                                0.000000
# geoNetwork.country                               0.000000
# geoNetwork.metro                                 0.000000
# geoNetwork.networkDomain                         0.000000
# year                                             0.000000
# geoNetwork.subContinent                          0.000000
# totals.hits                                      0.000000
# trafficSource.campaign                           0.000000
# trafficSource.medium                             0.000000
# trafficSource.source                             0.000000
# day                                              0.000000
# month                                            0.000000
# channelGrouping                                  0.000000
# dtype: float64

# %% [markdown]
# Dropping those columns which have NaN% greater than 75

# %%
drop_columns = ['trafficSource.adContent', 'trafficSource.adwordsClickInfo.page', 'trafficSource.adwordsClickInfo.slot', 'trafficSource.adwordsClickInfo.adNetworkType', 'trafficSource.adwordsClickInfo.gclId', 'trafficSource.referralPath']

# %%
X_train.drop(drop_columns, axis=1, inplace=True)
X_test.drop(drop_columns, axis=1, inplace=True)

# %%
X_train['trafficSource.keyword'].fillna('nan', inplace=True)
X_test['trafficSource.keyword'].fillna('nan', inplace=True)

# %%
def add_new_category(x):
    x = str(x).lower()
    if x == 'nan':
        return 'nan'
    
    x = ''.join(x.split())
    
    if 'youtube' in x or 'you' in x or 'yo' in x or 'tub' in x:
        return 'youtube'
    elif 'google' in x or 'goo' in x or 'gle' in x:
        return 'google'
    else:
        return 'other'

# %% [markdown]
# Majority of the data points contain trafficSource.keyword as either some substring of either google of youtube. Adding actual feature names in that column using the function.

# %%
X_train['trafficSource.keyword'] = X_train['trafficSource.keyword'].apply(add_new_category)
X_test['trafficSource.keyword'] = X_test['trafficSource.keyword'].apply(add_new_category)

# %%
X_train["totals.transactionRevenue"] = X_train["totals.transactionRevenue"].astype('float')

# %%
device_mobile_val = []
for i in X_train['device.isMobile'].unique():
    #t = X_train.loc[X_train['device.isMobile'] == i, 'totals.transactionRevenue'].mean()
    device_mobile_val.append(X_train.loc[X_train['device.isMobile'] == i, 'totals.transactionRevenue'].mean())

# %%
plt.figure(figsize = (9,5))
plt.subplot(1,2,1)
X_train['device.isMobile'].value_counts().sort_values(ascending = False).plot.bar()
plt.title('Device a mobile or not')
#plt.show()

plt.subplot(1,2,2)
plt.bar(['False', 'True'],device_mobile_val, width = 0.35, color = ['mediumblue','darkorange'], alpha = 0.8)
plt.title('Total Revenue as per mobile or not')
plt.tight_layout()
plt.show()

# %%
X_train['device.isMobile'] = X_train['device.isMobile'].astype(int)
X_test['device.isMobile'] = X_test['device.isMobile'].astype(int)

# %%
device_os = []
device_os_names = []

for i in X_train['device.operatingSystem'].unique():
    #t = X_train.loc[X_train['device.isMobile'] == i, 'totals.transactionRevenue'].mean()
    device_os.append(X_train.loc[X_train['device.operatingSystem'] == i, 'totals.transactionRevenue'].sum())
    device_os_names.append(i)
    
import math
for i in range (0,len(device_os)):
    if math.isnan(device_os[i]):
        device_os[i] = 0.0
    
device_os, device_os_names = (list(t) for t in zip(*sorted(zip(device_os, device_os_names))))
device_os.reverse()
device_os_names.reverse()

# %%
plt.figure(figsize = (15,10))
plt.subplot(2,1,1)

X_train['device.operatingSystem'].value_counts().sort_values(ascending = False).plot.bar()
plt.title('Number of devices according to their OS')

plt.subplot(2,1,2)
plt.xticks(rotation=90)

plt.bar(device_os_names , device_os, width = 0.5)
plt.title('Total Revenue according to OS')
plt.tight_layout()
plt.show()

# %%
browser_means = []
browser_names = []

for i in X_train['device.browser'].unique():
    #t = X_train.loc[X_train['device.isMobile'] == i, 'totals.transactionRevenue'].mean()
    browser_means.append(X_train.loc[X_train['device.browser'] == i, 'totals.transactionRevenue'].mean())
    browser_names.append(i)
    
for i in range (0,len(browser_means)):
    if math.isnan(browser_means[i]):
        browser_means[i] = 0.0
    
browser_means, browser_names = (list(t) for t in zip(*sorted(zip(browser_means, browser_names))))
browser_means.reverse()
browser_names.reverse()

# %%
plt.figure(figsize = (15,15))
plt.subplot(2,1,1)
#plt.yticks(np.arange(min(browser_means), max(browser_means) + 50000, 50000))
X_train['device.browser'].value_counts().sort_values(ascending = False).plot.bar()
plt.title('Number of devices according to their browsers')

plt.subplot(2,1,2)
plt.xticks(rotation=90)
#plt.yticks(np.arange(min(browser_means), max(browser_means) + 50000, 50000))
plt.bar(browser_names , browser_means, width = 0.5)
plt.title('Mean Revenue according to browsers')
plt.tight_layout()
plt.show()

# %%
X_train['logRev'] = np.log(X_train['totals.transactionRevenue'])
plt.figure(figsize = (5,10))
X_train.groupby("date")["logRev"].agg(['sum', 'count', 'mean']).plot(subplots=True, sharex=True, title="Revenue Based On Date", linewidth=2,figsize = (20,10))
plt.show()

# %%
X_train = X_train.drop(columns = ['logRev'])
X_train.drop('date', axis = 1, inplace = True)
X_test.drop('date', axis = 1, inplace = True)

# %%
crosstab_eda = pd.crosstab(index=X_train[X_train['device.operatingSystem']\
                                          .isin(X_train['device.operatingSystem']\
                                                .value_counts()[:6].index.values)]['device.operatingSystem'], 
                           
                           columns=X_train[X_train['device.browser'].isin(X_train['device.browser']\
                                                                            .value_counts()[:5].index.values)]['device.browser'])

crosstab_eda.plot(kind="bar",    
                 figsize=(14,7), 
                 stacked=True)  
plt.title("OS and Browser", fontsize=22) 
plt.xlabel("Operating System", fontsize=19) 
plt.ylabel("Count", fontsize=19) 
plt.xticks(rotation=0) 

plt.show()

# %%
X_train['totals.transactionRevenue'] = X_train['totals.transactionRevenue'].fillna(0).astype(float)

# %%
import math
geonetwork_means = []
geonetwork_names = []

for i in X_train['geoNetwork.continent'].unique():
    #t = X_train.loc[X_train['device.isMobile'] == i, 'totals.transactionRevenue'].mean()
    geonetwork_means.append(X_train.loc[X_train['geoNetwork.continent'] == i, 'totals.transactionRevenue'].sum())
    geonetwork_names.append(i)
    
for i in range (0,len(geonetwork_means)):
    if math.isnan(geonetwork_means[i]):
        geonetwork_means[i] = 0.0
    
geonetwork_means, geonetwork_names = (list(t) for t in zip(*sorted(zip(geonetwork_means, geonetwork_names))))
geonetwork_means.reverse()
geonetwork_names.reverse()

# %%
plt.figure(figsize = (17,13))
plt.subplot(221)
#plt.yticks(np.arange(min(browser_means), max(browser_means) + 50000, 50000))
X_train['geoNetwork.continent'].value_counts().sort_values(ascending = False).plot.bar()
plt.title('Visits per continent')

plt.subplot(222)
plt.xticks(rotation=90)
#plt.yticks(np.arange(min(browser_means), max(browser_means) + 50000, 50000))
plt.bar(geonetwork_names , geonetwork_means, width = 0.5)
plt.title('Total Revenue according to continents')
# Out:
# Text(0.5,1,'Total Revenue according to continents')

# %%
X_train.pivot_table(index='geoNetwork.continent', columns='channelGrouping', values='totals.transactionRevenue').plot(kind='bar', figsize = (20,5), width = 0.7)

# %%
import math
geonetwork_city_means = []
geonetwork_city_names = []
geonetwork_city_counts = []

for i in X_train['geoNetwork.city'].unique():
    #t = X_train.loc[X_train['device.isMobile'] == i, 'totals.transactionRevenue'].mean()
    geonetwork_city_means.append(X_train.loc[X_train['geoNetwork.city'] == i, 'totals.transactionRevenue'].sum())
    geonetwork_city_names.append(i)
    
    
geonetwork_city_means, geonetwork_city_names = (list(t) for t in zip(*sorted(zip(geonetwork_city_means, geonetwork_city_names))))
geonetwork_city_means.reverse()
geonetwork_city_names.reverse()

for i in geonetwork_city_names[1:11]:
    geonetwork_city_counts.append(X_train[X_train['geoNetwork.city'] == i].count()[0])

# %%
plt.figure(figsize = (17,13))
plt.subplot(221)
#plt.yticks(np.arange(min(browser_means), max(browser_means) + 50000, 50000))
tmp = X_train['geoNetwork.city'].value_counts().sort_values(ascending = False)
del tmp['(not set)']
tmp = tmp[1:11]
tmp.plot.bar()
#X_train['geoNetwork.city'].value_counts().sort_values(ascending = False).plot.bar()
plt.title('Visits per city')

plt.subplot(222)
plt.xticks(rotation=90)
#plt.yticks(np.arange(min(browser_means), max(browser_means) + 50000, 50000))
plt.bar(geonetwork_city_names[1:11] , geonetwork_city_means[1:11], width = 0.5)
plt.title('Total Revenue according to city')
# Out:
# Text(0.5,1,'Total Revenue according to city')

# %%
geonetwork_subconti_means = []
geonetwork_subconti_names = []

for i in X_train['geoNetwork.subContinent'].unique():
    #t = X_train.loc[X_train['device.isMobile'] == i, 'totals.transactionRevenue'].mean()
    geonetwork_subconti_means.append(X_train.loc[X_train['geoNetwork.subContinent'] == i, 'totals.transactionRevenue'].mean())
    geonetwork_subconti_names.append(i)
    
for i in range (0,len(geonetwork_subconti_means)):
    if math.isnan(geonetwork_subconti_means[i]):
        geonetwork_subconti_means[i] = 0.0
geonetwork_subconti_means, geonetwork_subconti_names = (list(t) for t in zip(*sorted(zip(geonetwork_subconti_means, geonetwork_subconti_names))))
geonetwork_subconti_means.reverse()
geonetwork_subconti_names.reverse()

# %%
plt.figure(figsize = (15,5))
plt.subplot(1,2,1)
#plt.yticks(np.arange(min(browser_means), max(browser_means) + 50000, 50000))
X_train['geoNetwork.subContinent'].value_counts().sort_values(ascending = False).plot.bar()
plt.title('Visits per continent')

plt.subplot(1,2,2)
plt.xticks(rotation=90)
#plt.yticks(np.arange(min(browser_means), max(browser_means) + 50000, 50000))
plt.bar(geonetwork_subconti_names , geonetwork_subconti_means, width = 0.5)
plt.title('Mean Revenue according to continents')
plt.tight_layout()
plt.show()

# %%
categorical = ['device.browser', 'device.deviceCategory', 'device.operatingSystem', 'geoNetwork.city', 'geoNetwork.continent' ,'geoNetwork.country', 'geoNetwork.metro', 'geoNetwork.networkDomain', 'geoNetwork.region', 'geoNetwork.subContinent']

# %% [markdown]
# Appending those features which are categorical in the list named "categorical". I will use this list later to encode labels to the categorical features.

# %%
plt.hist(np.log(X_train['totals.hits']))
plt.xticks(np.arange(0,20))
plt.show()

# %%
X_train['totals.pageviews'].fillna(0, inplace=True)
X_test['totals.pageviews'].fillna(0, inplace=True)

X_train['totals.pageviews'] = X_train['totals.pageviews'].astype(int)
X_test['totals.pageviews'] = X_test['totals.pageviews'].astype(int)

# %%
y1 = X_train['totals.hits']
x1 = X_train['totals.pageviews']


plt.figure(figsize = (7,7))
plt.scatter(x1, y1)
plt.xlabel('Page Views')
plt.ylabel('Hits')
plt.show()

# %%
x1 = X_train['totals.pageviews']
y1 = X_train['totals.transactionRevenue']

plt.scatter(x1, y1,s = 10)
plt.xticks(np.arange(0,500,step = 50))
plt.xlabel('totals.pageviews')
plt.ylabel('totals.trasacionRevenue')
plt.show()

# %%
X_train['hits_per_pageviews'] = (X_train["totals.hits"]/(X_train["totals.pageviews"])).apply(lambda x: 0 if np.isinf(x) else x)

# %%
x1 = X_train['hits_per_pageviews']
y1 = X_train['totals.transactionRevenue']

plt.scatter(x1, y1,s = 10)
plt.xticks(np.arange(0,100,step = 10))
plt.xlabel('hits_per_pageviews')
plt.ylabel('totals.trasacionRevenue')
plt.show()

# %%
X_train['channelGrouping'].unique()
# Out:
# array(['Organic Search', 'Referral', 'Paid Search', 'Affiliates',
#        'Direct', 'Display', 'Social', '(Other)'], dtype=object)

# %%
categorical.append('channelGrouping')

# %%
X_train['trafficSource.campaign'].unique()
# Out:
# array(['(not set)', 'AW - Dynamic Search Ads Whole Site',
#        'Data Share Promo', 'AW - Electronics', 'test-liyuhz',
#        'AW - Accessories',
#        'Retail (DO NOT EDIT owners nophakun and tianyu)', 'AW - Apparel',
#        'All Products', 'Data Share'], dtype=object)

# %%
categorical.append('trafficSource.campaign')

# %%
X_train['trafficSource.medium'].unique()
# Out:
# array(['organic', 'referral', 'cpc', 'affiliate', '(none)', 'cpm',
#        '(not set)'], dtype=object)

# %%
categorical.append('trafficSource.medium')

# %%
X_train['trafficSource.source'].unique()
# Out:
# array(['google', 'baidu', 'googleweblight.com', 'sites.google.com',
#        'bing', 'siliconvalley.about.com', 'analytics.google.com',
#        'Partners', '(direct)', 'mall.googleplex.com', 'google.com',
#        'google.co.in', 'qiita.com', 'google.pl', 'mail.google.com',
#        'hangouts.google.com', 'dealspotr.com', 'optimize.google.com',
#        'arstechnica.com', 'dfa', 'docs.google.com', 'sashihara.jp',
#        'google.gatewaycdi.com', 'phandroid.com', 'images.google',
#        'youtube.com', 'l.facebook.com', 'facebook.com', 'quora.com',
#        'm.facebook.com', 'reddit.com', 'google.co.jp', 'aol',
#        'moma.corp.google.com', 'blog.golang.org', 'yahoo', 't.co',
#        'nordic.businessinsider.com', 'duckduckgo.com', 'm.baidu.com',
#        'tpc.googlesyndication.com', 'googleads.g.doubleclick.net',
#        '0.shared.bow.cat2.ads-bow.vu.borg.google.com:9856',
#        'online-metrics.com', 'cv.il3.ub.edu', 'gophergala.com',
#        'plus.google.com', 's0.2mdn.net', 'keep.google.com',
#        'svirkar.mtv.corp.google.com:8888', 'connect.googleforwork.com',
#        'google.com.pk', 'support.google.com', 'gdeals.googleplex.com',
#        'google.com.au', 'int.search.tb.ask.com', 'googleux.perksplus.com',
#        'groups.google.com', 'm.youtube.com', 'productforums.google.com',
#        'web.skype.com', 'ask', 'search.mysearch.com',
#        'course.fso.fullsail.edu', 'google.co.uk',
#        'toronto.mtv.corp.google.com:8080', 'awics.corp.google.com',
#        'aulagrado.esic.edu', 'businessinsider.com', 'outlook.live.com',
#        'lunametrics.com', 'search.tb.ask.com', 'm.reddit.com',
#        '0.shared.bow.cat2.ads-bow.qk.borg.google.com:9801', 'new.vk.com',
#        'linkedin.com', 'm.vk.com', 'google.com.sg', 'lnkd.in',
#        'col128.mail.live.com', 'gsuite.google.com', 'google.ru',
#        'staging.talkgadget.google.com',
#        '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9875',
#        'analytics.corp.google.com', 'us.search.yahoo.com',
#        'search.xfinity.com', 'plus.url.google.com', 'google.com.ua',
#        'csfirst.withgoogle.com', 'yandex', 'm.sogou.com',
#        '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9850',
#        'images.google.de', 'google.ro', 'pinterest.com', 'google.com.br',
#        'it.search.yahoo.com', 'google.ca', 'google.es',
#        '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9815',
#        'google.co.th', 'mail.aol.com', 'cases.corp.google.com',
#        'cc.csusm.edu', 'grow.googleplex.com', 'feedly.com',
#        'uk.search.yahoo.com', 'lm.facebook.com', 'web.facebook.com',
#        'sg.search.yahoo.com', 'search.incredibar.com',
#        'malaysia.search.yahoo.com', 'github.com', 'google.fr',
#        'suche.t-online.de', 'adwords.google.com',
#        'dynamite.sandbox.google.com', 'g3doc.corp.google.com',
#        'ca.search.yahoo.com', 'drawnames.com', 'search.earthlink.net',
#        'amazon.com', 'tw.search.yahoo.com', 'l.messenger.com',
#        'inbox.google.com', 'au.search.yahoo.com', 'se.search.yahoo.com',
#        'google.cl', '(not set)', 'mg.mail.yahoo.com', 'msn.com',
#        'apis.mail.yahoo.com',
#        '0.shared.bow.cat2.ads-bow.lf.borg.google.com:9857',
#        'google.com.vn', 'ph.search.yahoo.com', 'google.com.tw',
#        'away.vk.com', 'datastudio.google.com', 'learn.temple.edu',
#        'plus.sandbox.google.com', 'messenger.com', 'wap.sogou.com',
#        'kristiyan.users.x20web.corp.google.com', 'google.ch',
#        'trainup.withgoogle.com', 'getpocket.com', 'startpage.com',
#        'google.com.co', 'google.co.kr',
#        'mail-attachment.googleusercontent.com',
#        'nl.yhs4.search.yahoo.com', 'luyaochen.mtv.corp.google.com:8080',
#        'myactivity.google.com', 'google.it', 'newclasses.nyu.edu',
#        'google.com.hk', 'blognone.com',
#        '0.shared.bow.cat2.ads-bow.lf.borg.google.com:9898',
#        'seroundtable.com', 'gatewaycdi.com', 'vk.com',
#        'in.search.yahoo.com', 'ics-devel-west.qa.adz.google.com',
#        'google.de', 'google.com.ph', 'm.mg.mail.yahoo.com',
#        'squishable.com', 'twitter.com', 'images.google.ie',
#        'marketingland.com', 'kik.com', 'uweoconnect.extn.washington.edu',
#        'adwords-displayads.googleusercontent.com', 'mysearch.com',
#        'flipboard.com', 'uk.businessinsider.com', 'baidu.com',
#        'images.google.co.id', 'de.pinterest.com',
#        'se.yhs4.search.yahoo.com', 'gtm-preprod-dogfood.corp.google.com',
#        '0.shared.bow.cat2.ads-bow.qk.borg.google.com:9848',
#        'watchword.googleplex.com', 'cn.bing.com', 'google.nl',
#        'web.telegram.org', 'images.google.lk',
#        'notifications.sandbox.google.com', 'h.yandex-team.ru',
#        'plusapp.sandbox.google.com', 'nl.search.yahoo.com', 'm.yz.sm.cn',
#        'cl-cards.googleplex.com', 'chatwork.com', 'wheretoget.it',
#        'images.google.fr', 'google.com.mx', 'localhost', 'google.cz',
#        'admin.globalaccess.com', 'online.fullsail.edu', 'tumblr.com',
#        'desktop.google.com.ua', 'fr.search.yahoo.com',
#        'business.facebook.com', 'getiriver.com',
#        'xbidprodmirror.corp.google.com',
#        '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9820',
#        'google.co.id', 'allo.corp.google.com', 'amp.reddit.com',
#        '0.shared.bow.cat2.ads-bow.qk.borg.google.com:9885',
#        'en.wikipedia.org', 'kr.pinterest.com', 'finance.yahoo.com',
#        'adwords-next-nightly.qa.adz.google.com',
#        'markets.businessinsider.com', 'google.co.nz',
#        '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9835',
#        '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9856',
#        'adwords-next-devel.qa.adz.google.com', 'us-mg5.mail.yahoo.com',
#        'kidrex.org', '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9861',
#        'earth.google.com', 'goto.google.com', 'so.com', 'cse.google.com',
#        'crowdcompute.googleplex.com', 'spaces.google.com',
#        '0.shared.bow.cat2.ads-bow.vu.borg.google.com:9859',
#        'mobile.facebook.com', 'google.bg', 'news.ycombinator.com',
#        'search.1and1.com', 'learn.colorado.edu', 'search.snapdo.com',
#        'msn', 'start.wow.com', 'us.yhs4.search.yahoo.com', 'bing.com',
#        'ex.fit.edu', 'searchlock.com', 'google.sk',
#        'fr.yhs4.search.yahoo.com',
#        '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9896', 'centrum.cz',
#        'ddimitrop.irv.corp.google.com:9001',
#        '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9892',
#        'calendar.google.com', 'search.myway.com', 'google.gr',
#        'ausdroid.net', 'gdeals-stg.googleplex.com', 'google.be',
#        'es.search.yahoo.com', 'int.search.mywebsearch.com',
#        'x20web.corp.google.com', 'dailydot.com',
#        'redbull.corp.google.com', 'oct-obscura.sandbox.google.com',
#        '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9849',
#        'google.co.za', 'images.google.co.in',
#        '0.shared.bow.cat2.ads-bow.qk.borg.google.com:9819',
#        'plusapp-autopush.corp.google.com', 'login.corp.google.com',
#        'maktoob.search.yahoo.com',
#        '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9880',
#        'invincible.mtv.corp.google.com:8080', 'go.mail.ru',
#        '0.muppet1.frontend.gws.muppet-exp.ij-q.borg.google.com:14634',
#        'basecamp.com',
#        '0.shared.bow.cat2.ads-bow.qk.borg.google.com:9831',
#        '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9885',
#        '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9816',
#        'benkraft.mtv.corp.google.com:9000',
#        '0.shared.bow.cat2.ads-bow.tg.borg.google.com:9864',
#        'chat.google.com', 'myaccount.google.com',
#        '0.shared.bow.cat2.ads-bow.vu.borg.google.com:9883', 'google.se',
#        'blackboard.neu.edu', 'fletch.teams.x20web.corp.google.com',
#        'evernote.com',
#        '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9862', 'ixquick.com',
#        'search.pch.com', 'mail.verizon.com', 'google.co.il', 'wanelo.com',
#        'images.google.at',
#        '0.shared.bow.cat2.ads-bow.lf.borg.google.com:9879',
#        'adwords-displayads-nightly.corp.google.com',
#        '0.shared.bow.cat2.ads-bow.lf.borg.google.com:9817',
#        'google.com.sa',
#        '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9859',
#        'br.pinterest.com', 'pinpoint.corp.google.com',
#        'prod.facebook.com',
#        '0.shared.bow.cat2.ads-bow.lf.borg.google.com:9824', 'lmgtfy.com',
#        'collaborate.northwestern.edu', 'members.s7.exacttarget.com',
#        'wunderbin.corp.google.com', 'google.at', 'images.google.lt',
#        'web.mail.comcast.net',
#        '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9836',
#        'google.com.ng',
#        '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9839',
#        'ad.doubleclick.net', 'oscar.corp.google.com',
#        'growcms.googleplex.com', 'web.whatsapp.com',
#        'dena-design.qiita.com',
#        '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9895',
#        'papyrus.mtv.corp.google.com:9021', 'yt-go-12345.googleplex.com',
#        'google.rs', '0.shared.bow.cat2.ads-bow.qk.borg.google.com:9899',
#        'ps-dm.reddit.com', 'blackboard.towson.edu',
#        'risk360-prod.corp.google.com', 'images.google.com.au',
#        'us.reddit.com', 'google.no',
#        '0.shared.bow.cat2.ads-bow.vk.borg.google.com:9878',
#        '0.shared.bow.cat2.ads-bow.qk.borg.google.com:9830',
#        'adwords-prod-west.qa.adz.google.com',
#        'brewmaster.corp.google.com',
#        '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9801',
#        'computerworld.com',
#        '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9865',
#        '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9851',
#        '0.shared.bow.cat2.ads-bow.vw.borg.google.com:9891', 'digg.com',
#        'it-mg42.mail.yahoo.com', 'intranet', '9to5google.com',
#        '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9813',
#        '0.shared.bow.cat2.ads-bow.qk.borg.google.com:9846',
#        'images.google.pt', 'google.lk', 'businessinsider.in',
#        'newsstand.google.com', 'yahoo.com', 'moodle.aurora.edu',
#        '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9858',
#        'gtm-dogfood.corp.google.com', 'tweetdeck.twitter.com',
#        'br.search.yahoo.com', 'hosted.verticalresponse.com',
#        '0.shared.bow.cat2.ads-bow.qk.borg.google.com:9859',
#        'cases2.corp.google.com', 'mx.search.yahoo.com',
#        '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9847',
#        'biztools.corp.google.com', 'us.wow.com', 'm.sp.sm.cn',
#        'hk.search.yahoo.com', 'voice.google.com', 's7-eu4.ixquick.com',
#        'espanol.search.yahoo.com', 'meetup.com',
#        '0.shared.bow.cat2.ads-bow.tl.borg.google.com:9847',
#        'google.com.ar', 'id.search.yahoo.com', 'it.pinterest.com',
#        'mmisciagna2.sbo.corp.google.com:8000', 'google.com.pe',
#        '0.shared.bow.cat2.ads-bow.qk.borg.google.com:9834',
#        'good.barkpost.com', 'gist.github.com',
#        '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9876',
#        'takeout.google.com',
#        '0.shared.bow.cat2.ads-bow.qk.borg.google.com:9873',
#        '0.shared.bow.cat2.ads-bow.lf.borg.google.com:9860',
#        '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9898'], dtype=object)

# %%
def add_new_category(x):
    x = str(x).lower()
    if 'google' in x:
        return 'google'
    elif 'baidu' in x:
        return 'baidu'
    elif 'facebook' in x:
        return 'facebook'
    elif 'reddit' in x:
        return 'reddit'
    elif 'yahoo' in x:
        return 'yahoo'
    elif 'bing' in x:
        return 'bing'
    elif 'yandex' in x:
        return 'yandex'
    else:
        return 'other'

# %% [markdown]
# Identified some repeating values in trafficSource.source. Wrote a function to add the actual names from the substrings in the column.

# %%
X_train['trafficSource.source'] = X_train['trafficSource.source'].apply(add_new_category)
X_test['trafficSource.source'] = X_test['trafficSource.source'].apply(add_new_category)

# %%
X_train.head()
# Out:
#   channelGrouping        ...         hits_per_pageviews
# 0  Organic Search        ...                        1.0
# 1  Organic Search        ...                        1.0
# 2  Organic Search        ...                        1.0
# 3  Organic Search        ...                        1.0
# 4  Organic Search        ...                        1.0
#
# [5 rows x 29 columns]

# %%
X_train['channelGrouping'].unique()
# Out:
# array(['Organic Search', 'Referral', 'Paid Search', 'Affiliates',
#        'Direct', 'Display', 'Social', '(Other)'], dtype=object)

# %%
X_train.head()

# %%
len_Xtrain = X_train.shape[0]
len_Xtrain
# Out:
# 903653

# %% [markdown]
# Deleting the output value from the dataset.

# %%
#X_train['totals.transactionRevenue'] = X_train['totals.transactionRevenue'].fillna(0).astype(float)
Y_train = X_train['totals.transactionRevenue'].fillna(0).astype(float)
Y_train = Y_train.apply(lambda x: np.log(x) if x > 0 else x)
del X_train['totals.transactionRevenue']

# %%
df_all = pd.concat([X_train, X_test])
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Appending more categorical values

# %%
categorical += ['day', 'month', 'year', 'weekOfTheYear', 'trafficSource.source', 'trafficSource.keyword', 'trafficSource.medium']

# %%
categorical
# Out:
# ['device.browser',
#  'device.deviceCategory',
#  'device.operatingSystem',
#  'geoNetwork.city',
#  'geoNetwork.continent',
#  'geoNetwork.country',
#  'geoNetwork.metro',
#  'geoNetwork.networkDomain',
#  'geoNetwork.region',
#  'geoNetwork.subContinent',
#  'channelGrouping',
#  'trafficSource.campaign',
#  'day',
#  'month',
#  'year',
#  'weekOfTheYear',
#  'trafficSource.source',
#  'trafficSource.keyword']

# %%
X_train['totals.transactionRevenue'] = Y_train

# %%
X_train.head()

# %% [markdown]
# For buyer prediction, creating a copy of X_train and adding buyornobuy feature to it.

# %%
prob_df = X_train
prob_df.loc[X_train['totals.transactionRevenue']>0, 'buyornobuy'] = 1
prob_df.loc[X_train['totals.transactionRevenue']<=0, 'buyornobuy'] = 0
prob_df.tail()
# Out:
#        channelGrouping    ...     buyornobuy
# 903648          Social    ...            0.0
# 903649          Social    ...            0.0
# 903650          Social    ...            0.0
# 903651          Social    ...            0.0
# 903652          Social    ...            0.0
#
# [5 rows x 30 columns]

# %% [markdown]
# Label encoding the newly created df

# %%
from sklearn.preprocessing import LabelEncoder
for col in categorical:
    lbl = LabelEncoder()
    prob_df[col] = lbl.fit_transform(prob_df[col])

# %%
prob_df.head()
# Out:
#    channelGrouping    ...     buyornobuy
# 0                4    ...            0.0
# 1                4    ...            0.0
# 2                4    ...            0.0
# 3                4    ...            0.0
# 4                4    ...            0.0
#
# [5 rows x 30 columns]

# %% [markdown]
# Before training LGBM for predicting probability scores.

# %%
tmp_probdf = pd.DataFrame()
tmp_probdf['fullVisitorId'] = prob_df['fullVisitorId']
tmp_probdf['sessionId'] = prob_df['sessionId']
tmp_probdf['visitId'] = prob_df['visitId']
prob_df.drop(['fullVisitorId', 'sessionId', 'visitId'], inplace = True, axis = 1)
prob_df.head()
# Out:
#    channelGrouping     ...      buyornobuy
# 0                4     ...             0.0
# 1                4     ...             0.0
# 2                4     ...             0.0
# 3                4     ...             0.0
# 4                4     ...             0.0
#
# [5 rows x 27 columns]

# %%
from sklearn.model_selection import StratifiedKFold
import lightgbm as lgb
FOLDs = StratifiedKFold(n_splits=10, shuffle=True, random_state=7)
clf = lgb.LGBMClassifier(class_weight='balanced', objective= 'binary',max_depth=8, colsample_bytree=0.8,learning_rate=0.01, min_child_samples=20, reg_alpha=1, reg_lambda=1, 
                    num_leaves=257, subsample=0.8)

# %%
X = prob_df.loc[:, categorical]
Y = prob_df["buyornobuy"]

# %%
oof_lgb = np.zeros(len(prob_df))
predictions_lgb = np.zeros(len(prob_df))

# %%
features_lgb = list(X.columns)
feature_importance_df_lgb = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(FOLDs.split(X, Y)):
    trn_data = lgb.Dataset(X.iloc[trn_idx], label=Y.iloc[trn_idx])
    val_data = lgb.Dataset(X.iloc[val_idx], label=Y.iloc[val_idx])

# %%
for fold_, (trn_idx, val_idx) in enumerate(FOLDs.split(X, Y)):
    trn_data = lgb.Dataset(X.iloc[trn_idx], label=Y.iloc[trn_idx])
    val_data = lgb.Dataset(X.iloc[val_idx], label=Y.iloc[val_idx])

    print("LGB " + str(fold_) + "-" * 50)
    num_round = 20000
    clf.fit(trn_data.data, trn_data.label, eval_set = [(val_data.data, val_data.label)], verbose = True, early_stopping_rounds = 100)
    oof_lgb[val_idx] = clf.predict(X.iloc[val_idx], num_iteration=clf.best_iteration_)
    fold_importance_df_lgb = pd.DataFrame()
    fold_importance_df_lgb["feature"] = features_lgb
    fold_importance_df_lgb["importance"] = clf.feature_importances_
    fold_importance_df_lgb["fold"] = fold_ + 1
    feature_importance_df_lgb = pd.concat([feature_importance_df_lgb, fold_importance_df_lgb], axis=0)
    #clf_model.booster_ = clf
    #predictions_lgb += clf.predict_proba(X, num_iteration=clf.best_iteration_) / FOLDs.n_splits
# Out:
# LGB 0--------------------------------------------------
# [1]	valid_0's binary_logloss: 0.688412
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's binary_logloss: 0.683949
# [3]	valid_0's binary_logloss: 0.679427
# [4]	valid_0's binary_logloss: 0.674992
# [5]	valid_0's binary_logloss: 0.670692
# [6]	valid_0's binary_logloss: 0.666556
# [7]	valid_0's binary_logloss: 0.66258
# [8]	valid_0's binary_logloss: 0.658699
# [9]	valid_0's binary_logloss: 0.654701
# [10]	valid_0's binary_logloss: 0.650948
# [11]	valid_0's binary_logloss: 0.647133
# [12]	valid_0's binary_logloss: 0.643589
# [13]	valid_0's binary_logloss: 0.640067
# [14]	valid_0's binary_logloss: 0.636488
# [15]	valid_0's binary_logloss: 0.632973
# [16]	valid_0's binary_logloss: 0.629671
# [17]	valid_0's binary_logloss: 0.626463
# [18]	valid_0's binary_logloss: 0.623154
# [19]	valid_0's binary_logloss: 0.619912
# [20]	valid_0's binary_logloss: 0.61675
# [21]	valid_0's binary_logloss: 0.613709
# [22]	valid_0's binary_logloss: 0.610745
# [23]	valid_0's binary_logloss: 0.607759
# [24]	valid_0's binary_logloss: 0.604883
# [25]	valid_0's binary_logloss: 0.602078
# [26]	valid_0's binary_logloss: 0.599269
# [27]	valid_0's binary_logloss: 0.596513
# [28]	valid_0's binary_logloss: 0.593794
# [29]	valid_0's binary_logloss: 0.591137
# [30]	valid_0's binary_logloss: 0.588519
# [31]	valid_0's binary_logloss: 0.586078
# [32]	valid_0's binary_logloss: 0.583555
# [33]	valid_0's binary_logloss: 0.581118
# [34]	valid_0's binary_logloss: 0.578712
# [35]	valid_0's binary_logloss: 0.576397
# [36]	valid_0's binary_logloss: 0.574141
# [37]	valid_0's binary_logloss: 0.571845
# [38]	valid_0's binary_logloss: 0.569659
# [39]	valid_0's binary_logloss: 0.567445
# [40]	valid_0's binary_logloss: 0.565357
# [41]	valid_0's binary_logloss: 0.563221
# [42]	valid_0's binary_logloss: 0.561195
# [43]	valid_0's binary_logloss: 0.559208
# [44]	valid_0's binary_logloss: 0.557265
# [45]	valid_0's binary_logloss: 0.555299
# [46]	valid_0's binary_logloss: 0.553357
# [47]	valid_0's binary_logloss: 0.55144
# [48]	valid_0's binary_logloss: 0.549583
# [49]	valid_0's binary_logloss: 0.547748
# [50]	valid_0's binary_logloss: 0.54599
# [51]	valid_0's binary_logloss: 0.544206
# [52]	valid_0's binary_logloss: 0.542467
# [53]	valid_0's binary_logloss: 0.540808
# [54]	valid_0's binary_logloss: 0.539132
# [55]	valid_0's binary_logloss: 0.537465
# [56]	valid_0's binary_logloss: 0.535872
# [57]	valid_0's binary_logloss: 0.534264
# [58]	valid_0's binary_logloss: 0.53272
# [59]	valid_0's binary_logloss: 0.531181
# [60]	valid_0's binary_logloss: 0.529717
# [61]	valid_0's binary_logloss: 0.528315
# [62]	valid_0's binary_logloss: 0.526844
# [63]	valid_0's binary_logloss: 0.525402
# [64]	valid_0's binary_logloss: 0.524089
# [65]	valid_0's binary_logloss: 0.522727
# [66]	valid_0's binary_logloss: 0.521409
# [67]	valid_0's binary_logloss: 0.520061
# [68]	valid_0's binary_logloss: 0.518734
# [69]	valid_0's binary_logloss: 0.517439
# [70]	valid_0's binary_logloss: 0.51619
# [71]	valid_0's binary_logloss: 0.514986
# [72]	valid_0's binary_logloss: 0.513791
# [73]	valid_0's binary_logloss: 0.512588
# [74]	valid_0's binary_logloss: 0.511409
# [75]	valid_0's binary_logloss: 0.510252
# [76]	valid_0's binary_logloss: 0.509102
# [77]	valid_0's binary_logloss: 0.507996
# [78]	valid_0's binary_logloss: 0.506919
# [79]	valid_0's binary_logloss: 0.505852
# [80]	valid_0's binary_logloss: 0.504776
# [81]	valid_0's binary_logloss: 0.503759
# [82]	valid_0's binary_logloss: 0.502709
# [83]	valid_0's binary_logloss: 0.50167
# [84]	valid_0's binary_logloss: 0.500656
# [85]	valid_0's binary_logloss: 0.499646
# [86]	valid_0's binary_logloss: 0.49869
# [87]	valid_0's binary_logloss: 0.497696
# [88]	valid_0's binary_logloss: 0.496753
# [89]	valid_0's binary_logloss: 0.495825
# [90]	valid_0's binary_logloss: 0.494883
# [91]	valid_0's binary_logloss: 0.493975
# [92]	valid_0's binary_logloss: 0.493088
# [93]	valid_0's binary_logloss: 0.492189
# [94]	valid_0's binary_logloss: 0.491362
# [95]	valid_0's binary_logloss: 0.490513
# [96]	valid_0's binary_logloss: 0.489665
# [97]	valid_0's binary_logloss: 0.488863
# [98]	valid_0's binary_logloss: 0.488023
# [99]	valid_0's binary_logloss: 0.48725
# [100]	valid_0's binary_logloss: 0.486548
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's binary_logloss: 0.486548
# /opt/conda/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# LGB 1--------------------------------------------------
# [1]	valid_0's binary_logloss: 0.688425
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's binary_logloss: 0.684006
# [3]	valid_0's binary_logloss: 0.679475
# [4]	valid_0's binary_logloss: 0.675049
# [5]	valid_0's binary_logloss: 0.670752
# [6]	valid_0's binary_logloss: 0.66662
# [7]	valid_0's binary_logloss: 0.662647
# [8]	valid_0's binary_logloss: 0.658773
# [9]	valid_0's binary_logloss: 0.654776
# [10]	valid_0's binary_logloss: 0.65106
# [11]	valid_0's binary_logloss: 0.647258
# [12]	valid_0's binary_logloss: 0.64373
# [13]	valid_0's binary_logloss: 0.640215
# [14]	valid_0's binary_logloss: 0.636642
# [15]	valid_0's binary_logloss: 0.633134
# [16]	valid_0's binary_logloss: 0.629841
# [17]	valid_0's binary_logloss: 0.626639
# [18]	valid_0's binary_logloss: 0.623322
# [19]	valid_0's binary_logloss: 0.620078
# [20]	valid_0's binary_logloss: 0.61691
# [21]	valid_0's binary_logloss: 0.613858
# [22]	valid_0's binary_logloss: 0.610904
# [23]	valid_0's binary_logloss: 0.607922
# [24]	valid_0's binary_logloss: 0.605042
# [25]	valid_0's binary_logloss: 0.602227
# [26]	valid_0's binary_logloss: 0.599414
# [27]	valid_0's binary_logloss: 0.59666
# [28]	valid_0's binary_logloss: 0.593936
# [29]	valid_0's binary_logloss: 0.591283
# [30]	valid_0's binary_logloss: 0.588672
# [31]	valid_0's binary_logloss: 0.58623
# [32]	valid_0's binary_logloss: 0.583705
# [33]	valid_0's binary_logloss: 0.581262
# [34]	valid_0's binary_logloss: 0.578862
# [35]	valid_0's binary_logloss: 0.576545
# [36]	valid_0's binary_logloss: 0.574294
# [37]	valid_0's binary_logloss: 0.571989
# [38]	valid_0's binary_logloss: 0.569788
# [39]	valid_0's binary_logloss: 0.567571
# [40]	valid_0's binary_logloss: 0.565488
# [41]	valid_0's binary_logloss: 0.563345
# [42]	valid_0's binary_logloss: 0.561307
# [43]	valid_0's binary_logloss: 0.559348
# [44]	valid_0's binary_logloss: 0.557405
# [45]	valid_0's binary_logloss: 0.55543
# [46]	valid_0's binary_logloss: 0.553482
# [47]	valid_0's binary_logloss: 0.551559
# [48]	valid_0's binary_logloss: 0.549686
# [49]	valid_0's binary_logloss: 0.547847
# [50]	valid_0's binary_logloss: 0.54609
# [51]	valid_0's binary_logloss: 0.544299
# [52]	valid_0's binary_logloss: 0.54256
# [53]	valid_0's binary_logloss: 0.540902
# [54]	valid_0's binary_logloss: 0.539211
# [55]	valid_0's binary_logloss: 0.537534
# [56]	valid_0's binary_logloss: 0.53595
# [57]	valid_0's binary_logloss: 0.534342
# [58]	valid_0's binary_logloss: 0.5328
# [59]	valid_0's binary_logloss: 0.531259
# [60]	valid_0's binary_logloss: 0.5298
# [61]	valid_0's binary_logloss: 0.528396
# [62]	valid_0's binary_logloss: 0.526913
# [63]	valid_0's binary_logloss: 0.525462
# [64]	valid_0's binary_logloss: 0.524138
# [65]	valid_0's binary_logloss: 0.522783
# [66]	valid_0's binary_logloss: 0.521477
# [67]	valid_0's binary_logloss: 0.52012
# [68]	valid_0's binary_logloss: 0.51879
# [69]	valid_0's binary_logloss: 0.517503
# [70]	valid_0's binary_logloss: 0.516248
# [71]	valid_0's binary_logloss: 0.515045
# [72]	valid_0's binary_logloss: 0.513832
# [73]	valid_0's binary_logloss: 0.512636
# [74]	valid_0's binary_logloss: 0.511467
# [75]	valid_0's binary_logloss: 0.510307
# [76]	valid_0's binary_logloss: 0.509138
# [77]	valid_0's binary_logloss: 0.50803
# [78]	valid_0's binary_logloss: 0.506958
# [79]	valid_0's binary_logloss: 0.505897
# [80]	valid_0's binary_logloss: 0.504816
# [81]	valid_0's binary_logloss: 0.503811
# [82]	valid_0's binary_logloss: 0.502767
# [83]	valid_0's binary_logloss: 0.501718
# [84]	valid_0's binary_logloss: 0.500683
# [85]	valid_0's binary_logloss: 0.499665
# [86]	valid_0's binary_logloss: 0.498708
# [87]	valid_0's binary_logloss: 0.497703
# [88]	valid_0's binary_logloss: 0.496761
# [89]	valid_0's binary_logloss: 0.495839
# [90]	valid_0's binary_logloss: 0.494902
# [91]	valid_0's binary_logloss: 0.493974
# [92]	valid_0's binary_logloss: 0.493113
# [93]	valid_0's binary_logloss: 0.492206
# [94]	valid_0's binary_logloss: 0.491363
# [95]	valid_0's binary_logloss: 0.490485
# [96]	valid_0's binary_logloss: 0.489618
# [97]	valid_0's binary_logloss: 0.488807
# [98]	valid_0's binary_logloss: 0.487971
# [99]	valid_0's binary_logloss: 0.487194
# [100]	valid_0's binary_logloss: 0.486479
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's binary_logloss: 0.486479
# /opt/conda/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# LGB 2--------------------------------------------------
# [1]	valid_0's binary_logloss: 0.688424
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's binary_logloss: 0.683995
# [3]	valid_0's binary_logloss: 0.679484
# [4]	valid_0's binary_logloss: 0.675054
# [5]	valid_0's binary_logloss: 0.670777
# [6]	valid_0's binary_logloss: 0.666652
# [7]	valid_0's binary_logloss: 0.662702
# [8]	valid_0's binary_logloss: 0.658846
# [9]	valid_0's binary_logloss: 0.65485
# [10]	valid_0's binary_logloss: 0.651133
# [11]	valid_0's binary_logloss: 0.647331
# [12]	valid_0's binary_logloss: 0.643809
# [13]	valid_0's binary_logloss: 0.640317
# [14]	valid_0's binary_logloss: 0.636748
# [15]	valid_0's binary_logloss: 0.633254
# [16]	valid_0's binary_logloss: 0.62998
# [17]	valid_0's binary_logloss: 0.626782
# [18]	valid_0's binary_logloss: 0.623486
# [19]	valid_0's binary_logloss: 0.620251
# [20]	valid_0's binary_logloss: 0.617091
# [21]	valid_0's binary_logloss: 0.614047
# [22]	valid_0's binary_logloss: 0.611101
# [23]	valid_0's binary_logloss: 0.608125
# [24]	valid_0's binary_logloss: 0.605245
# [25]	valid_0's binary_logloss: 0.602438
# [26]	valid_0's binary_logloss: 0.599621
# [27]	valid_0's binary_logloss: 0.596873
# [28]	valid_0's binary_logloss: 0.594159
# [29]	valid_0's binary_logloss: 0.591508
# [30]	valid_0's binary_logloss: 0.588897
# [31]	valid_0's binary_logloss: 0.586465
# [32]	valid_0's binary_logloss: 0.583948
# [33]	valid_0's binary_logloss: 0.581499
# [34]	valid_0's binary_logloss: 0.579124
# [35]	valid_0's binary_logloss: 0.576805
# [36]	valid_0's binary_logloss: 0.574573
# [37]	valid_0's binary_logloss: 0.572278
# [38]	valid_0's binary_logloss: 0.570095
# [39]	valid_0's binary_logloss: 0.567887
# [40]	valid_0's binary_logloss: 0.565809
# [41]	valid_0's binary_logloss: 0.563673
# [42]	valid_0's binary_logloss: 0.561642
# [43]	valid_0's binary_logloss: 0.559649
# [44]	valid_0's binary_logloss: 0.557705
# [45]	valid_0's binary_logloss: 0.555744
# [46]	valid_0's binary_logloss: 0.553806
# [47]	valid_0's binary_logloss: 0.551888
# [48]	valid_0's binary_logloss: 0.550032
# [49]	valid_0's binary_logloss: 0.548196
# [50]	valid_0's binary_logloss: 0.546426
# [51]	valid_0's binary_logloss: 0.544642
# [52]	valid_0's binary_logloss: 0.542912
# [53]	valid_0's binary_logloss: 0.541231
# [54]	valid_0's binary_logloss: 0.539545
# [55]	valid_0's binary_logloss: 0.537871
# [56]	valid_0's binary_logloss: 0.536279
# [57]	valid_0's binary_logloss: 0.534667
# [58]	valid_0's binary_logloss: 0.533123
# [59]	valid_0's binary_logloss: 0.531582
# [60]	valid_0's binary_logloss: 0.530108
# [61]	valid_0's binary_logloss: 0.528717
# [62]	valid_0's binary_logloss: 0.527241
# [63]	valid_0's binary_logloss: 0.525789
# [64]	valid_0's binary_logloss: 0.524477
# [65]	valid_0's binary_logloss: 0.523123
# [66]	valid_0's binary_logloss: 0.521812
# [67]	valid_0's binary_logloss: 0.520455
# [68]	valid_0's binary_logloss: 0.519124
# [69]	valid_0's binary_logloss: 0.517851
# [70]	valid_0's binary_logloss: 0.516602
# [71]	valid_0's binary_logloss: 0.515397
# [72]	valid_0's binary_logloss: 0.514207
# [73]	valid_0's binary_logloss: 0.513007
# [74]	valid_0's binary_logloss: 0.511814
# [75]	valid_0's binary_logloss: 0.510665
# [76]	valid_0's binary_logloss: 0.5095
# [77]	valid_0's binary_logloss: 0.50842
# [78]	valid_0's binary_logloss: 0.507345
# [79]	valid_0's binary_logloss: 0.506267
# [80]	valid_0's binary_logloss: 0.505188
# [81]	valid_0's binary_logloss: 0.504182
# [82]	valid_0's binary_logloss: 0.503133
# [83]	valid_0's binary_logloss: 0.502091
# [84]	valid_0's binary_logloss: 0.501065
# [85]	valid_0's binary_logloss: 0.50005
# [86]	valid_0's binary_logloss: 0.499088
# [87]	valid_0's binary_logloss: 0.498084
# [88]	valid_0's binary_logloss: 0.497128
# [89]	valid_0's binary_logloss: 0.496208
# [90]	valid_0's binary_logloss: 0.49527
# [91]	valid_0's binary_logloss: 0.494351
# [92]	valid_0's binary_logloss: 0.493478
# [93]	valid_0's binary_logloss: 0.492574
# [94]	valid_0's binary_logloss: 0.491738
# [95]	valid_0's binary_logloss: 0.490889
# [96]	valid_0's binary_logloss: 0.490039
# [97]	valid_0's binary_logloss: 0.48924
# [98]	valid_0's binary_logloss: 0.488409
# [99]	valid_0's binary_logloss: 0.487634
# [100]	valid_0's binary_logloss: 0.486926
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's binary_logloss: 0.486926
# /opt/conda/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# LGB 3--------------------------------------------------
# [1]	valid_0's binary_logloss: 0.688427
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's binary_logloss: 0.683979
# [3]	valid_0's binary_logloss: 0.679477
# [4]	valid_0's binary_logloss: 0.675058
# [5]	valid_0's binary_logloss: 0.670774
# [6]	valid_0's binary_logloss: 0.666652
# [7]	valid_0's binary_logloss: 0.662679
# [8]	valid_0's binary_logloss: 0.658802
# [9]	valid_0's binary_logloss: 0.654831
# [10]	valid_0's binary_logloss: 0.651097
# [11]	valid_0's binary_logloss: 0.647283
# [12]	valid_0's binary_logloss: 0.643759
# [13]	valid_0's binary_logloss: 0.640273
# [14]	valid_0's binary_logloss: 0.6367
# [15]	valid_0's binary_logloss: 0.63322
# [16]	valid_0's binary_logloss: 0.629915
# [17]	valid_0's binary_logloss: 0.626728
# [18]	valid_0's binary_logloss: 0.623442
# [19]	valid_0's binary_logloss: 0.620215
# [20]	valid_0's binary_logloss: 0.617059
# [21]	valid_0's binary_logloss: 0.614029
# [22]	valid_0's binary_logloss: 0.611073
# [23]	valid_0's binary_logloss: 0.608099
# [24]	valid_0's binary_logloss: 0.605219
# [25]	valid_0's binary_logloss: 0.602426
# [26]	valid_0's binary_logloss: 0.599606
# [27]	valid_0's binary_logloss: 0.596858
# [28]	valid_0's binary_logloss: 0.594147
# [29]	valid_0's binary_logloss: 0.591508
# [30]	valid_0's binary_logloss: 0.588904
# [31]	valid_0's binary_logloss: 0.586471
# [32]	valid_0's binary_logloss: 0.583962
# [33]	valid_0's binary_logloss: 0.581513
# [34]	valid_0's binary_logloss: 0.579143
# [35]	valid_0's binary_logloss: 0.576823
# [36]	valid_0's binary_logloss: 0.574574
# [37]	valid_0's binary_logloss: 0.572277
# [38]	valid_0's binary_logloss: 0.570089
# [39]	valid_0's binary_logloss: 0.567869
# [40]	valid_0's binary_logloss: 0.565802
# [41]	valid_0's binary_logloss: 0.563677
# [42]	valid_0's binary_logloss: 0.561646
# [43]	valid_0's binary_logloss: 0.559679
# [44]	valid_0's binary_logloss: 0.557723
# [45]	valid_0's binary_logloss: 0.555755
# [46]	valid_0's binary_logloss: 0.553816
# [47]	valid_0's binary_logloss: 0.551891
# [48]	valid_0's binary_logloss: 0.550022
# [49]	valid_0's binary_logloss: 0.548185
# [50]	valid_0's binary_logloss: 0.546431
# [51]	valid_0's binary_logloss: 0.544652
# [52]	valid_0's binary_logloss: 0.542916
# [53]	valid_0's binary_logloss: 0.541257
# [54]	valid_0's binary_logloss: 0.539571
# [55]	valid_0's binary_logloss: 0.537889
# [56]	valid_0's binary_logloss: 0.536285
# [57]	valid_0's binary_logloss: 0.534673
# [58]	valid_0's binary_logloss: 0.533121
# [59]	valid_0's binary_logloss: 0.531583
# [60]	valid_0's binary_logloss: 0.530094
# [61]	valid_0's binary_logloss: 0.5287
# [62]	valid_0's binary_logloss: 0.527225
# [63]	valid_0's binary_logloss: 0.525772
# [64]	valid_0's binary_logloss: 0.524449
# [65]	valid_0's binary_logloss: 0.523069
# [66]	valid_0's binary_logloss: 0.521749
# [67]	valid_0's binary_logloss: 0.520385
# [68]	valid_0's binary_logloss: 0.519044
# [69]	valid_0's binary_logloss: 0.517765
# [70]	valid_0's binary_logloss: 0.516502
# [71]	valid_0's binary_logloss: 0.515285
# [72]	valid_0's binary_logloss: 0.514095
# [73]	valid_0's binary_logloss: 0.512887
# [74]	valid_0's binary_logloss: 0.511692
# [75]	valid_0's binary_logloss: 0.510548
# [76]	valid_0's binary_logloss: 0.509393
# [77]	valid_0's binary_logloss: 0.508288
# [78]	valid_0's binary_logloss: 0.507203
# [79]	valid_0's binary_logloss: 0.506125
# [80]	valid_0's binary_logloss: 0.505041
# [81]	valid_0's binary_logloss: 0.504016
# [82]	valid_0's binary_logloss: 0.502957
# [83]	valid_0's binary_logloss: 0.501922
# [84]	valid_0's binary_logloss: 0.500895
# [85]	valid_0's binary_logloss: 0.499883
# [86]	valid_0's binary_logloss: 0.498897
# [87]	valid_0's binary_logloss: 0.497889
# [88]	valid_0's binary_logloss: 0.496947
# [89]	valid_0's binary_logloss: 0.496035
# [90]	valid_0's binary_logloss: 0.495091
# [91]	valid_0's binary_logloss: 0.494172
# [92]	valid_0's binary_logloss: 0.493292
# [93]	valid_0's binary_logloss: 0.49237
# [94]	valid_0's binary_logloss: 0.49154
# [95]	valid_0's binary_logloss: 0.490684
# [96]	valid_0's binary_logloss: 0.489827
# [97]	valid_0's binary_logloss: 0.489011
# [98]	valid_0's binary_logloss: 0.488157
# [99]	valid_0's binary_logloss: 0.487357
# [100]	valid_0's binary_logloss: 0.486636
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's binary_logloss: 0.486636
# /opt/conda/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# LGB 4--------------------------------------------------
# [1]	valid_0's binary_logloss: 0.688401
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's binary_logloss: 0.683948
# [3]	valid_0's binary_logloss: 0.679431
# [4]	valid_0's binary_logloss: 0.674975
# [5]	valid_0's binary_logloss: 0.670664
# [6]	valid_0's binary_logloss: 0.666504
# [7]	valid_0's binary_logloss: 0.662525
# [8]	valid_0's binary_logloss: 0.658639
# [9]	valid_0's binary_logloss: 0.654632
# [10]	valid_0's binary_logloss: 0.650894
# [11]	valid_0's binary_logloss: 0.647075
# [12]	valid_0's binary_logloss: 0.643534
# [13]	valid_0's binary_logloss: 0.639998
# [14]	valid_0's binary_logloss: 0.636409
# [15]	valid_0's binary_logloss: 0.632895
# [16]	valid_0's binary_logloss: 0.629573
# [17]	valid_0's binary_logloss: 0.626366
# [18]	valid_0's binary_logloss: 0.623052
# [19]	valid_0's binary_logloss: 0.619805
# [20]	valid_0's binary_logloss: 0.61662
# [21]	valid_0's binary_logloss: 0.613563
# [22]	valid_0's binary_logloss: 0.610583
# [23]	valid_0's binary_logloss: 0.60759
# [24]	valid_0's binary_logloss: 0.604678
# [25]	valid_0's binary_logloss: 0.601853
# [26]	valid_0's binary_logloss: 0.599032
# [27]	valid_0's binary_logloss: 0.596261
# [28]	valid_0's binary_logloss: 0.593529
# [29]	valid_0's binary_logloss: 0.590861
# [30]	valid_0's binary_logloss: 0.588235
# [31]	valid_0's binary_logloss: 0.585762
# [32]	valid_0's binary_logloss: 0.583229
# [33]	valid_0's binary_logloss: 0.58076
# [34]	valid_0's binary_logloss: 0.578332
# [35]	valid_0's binary_logloss: 0.575989
# [36]	valid_0's binary_logloss: 0.573737
# [37]	valid_0's binary_logloss: 0.571435
# [38]	valid_0's binary_logloss: 0.569226
# [39]	valid_0's binary_logloss: 0.567006
# [40]	valid_0's binary_logloss: 0.564903
# [41]	valid_0's binary_logloss: 0.562761
# [42]	valid_0's binary_logloss: 0.560709
# [43]	valid_0's binary_logloss: 0.558752
# [44]	valid_0's binary_logloss: 0.556783
# [45]	valid_0's binary_logloss: 0.554793
# [46]	valid_0's binary_logloss: 0.552838
# [47]	valid_0's binary_logloss: 0.550907
# [48]	valid_0's binary_logloss: 0.549024
# [49]	valid_0's binary_logloss: 0.547159
# [50]	valid_0's binary_logloss: 0.545385
# [51]	valid_0's binary_logloss: 0.543596
# [52]	valid_0's binary_logloss: 0.54184
# [53]	valid_0's binary_logloss: 0.540167
# [54]	valid_0's binary_logloss: 0.538459
# [55]	valid_0's binary_logloss: 0.536762
# [56]	valid_0's binary_logloss: 0.535162
# [57]	valid_0's binary_logloss: 0.533524
# [58]	valid_0's binary_logloss: 0.531957
# [59]	valid_0's binary_logloss: 0.530386
# [60]	valid_0's binary_logloss: 0.528921
# [61]	valid_0's binary_logloss: 0.527503
# [62]	valid_0's binary_logloss: 0.526019
# [63]	valid_0's binary_logloss: 0.524545
# [64]	valid_0's binary_logloss: 0.523221
# [65]	valid_0's binary_logloss: 0.521859
# [66]	valid_0's binary_logloss: 0.520557
# [67]	valid_0's binary_logloss: 0.519186
# [68]	valid_0's binary_logloss: 0.517845
# [69]	valid_0's binary_logloss: 0.516557
# [70]	valid_0's binary_logloss: 0.515286
# [71]	valid_0's binary_logloss: 0.51407
# [72]	valid_0's binary_logloss: 0.512864
# [73]	valid_0's binary_logloss: 0.511642
# [74]	valid_0's binary_logloss: 0.510474
# [75]	valid_0's binary_logloss: 0.509308
# [76]	valid_0's binary_logloss: 0.508141
# [77]	valid_0's binary_logloss: 0.50704
# [78]	valid_0's binary_logloss: 0.505953
# [79]	valid_0's binary_logloss: 0.504897
# [80]	valid_0's binary_logloss: 0.503815
# [81]	valid_0's binary_logloss: 0.502801
# [82]	valid_0's binary_logloss: 0.501756
# [83]	valid_0's binary_logloss: 0.500705
# [84]	valid_0's binary_logloss: 0.499664
# [85]	valid_0's binary_logloss: 0.498622
# [86]	valid_0's binary_logloss: 0.497654
# [87]	valid_0's binary_logloss: 0.49663
# [88]	valid_0's binary_logloss: 0.49568
# [89]	valid_0's binary_logloss: 0.494734
# [90]	valid_0's binary_logloss: 0.493776
# [91]	valid_0's binary_logloss: 0.492833
# [92]	valid_0's binary_logloss: 0.491954
# [93]	valid_0's binary_logloss: 0.49103
# [94]	valid_0's binary_logloss: 0.490179
# [95]	valid_0's binary_logloss: 0.489305
# [96]	valid_0's binary_logloss: 0.488426
# [97]	valid_0's binary_logloss: 0.487598
# [98]	valid_0's binary_logloss: 0.486748
# [99]	valid_0's binary_logloss: 0.485957
# [100]	valid_0's binary_logloss: 0.485239
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's binary_logloss: 0.485239
# /opt/conda/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# LGB 5--------------------------------------------------
# [1]	valid_0's binary_logloss: 0.68843
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's binary_logloss: 0.684001
# [3]	valid_0's binary_logloss: 0.679509
# [4]	valid_0's binary_logloss: 0.675099
# [5]	valid_0's binary_logloss: 0.670813
# [6]	valid_0's binary_logloss: 0.666695
# [7]	valid_0's binary_logloss: 0.662744
# [8]	valid_0's binary_logloss: 0.6589
# [9]	valid_0's binary_logloss: 0.654926
# [10]	valid_0's binary_logloss: 0.651218
# [11]	valid_0's binary_logloss: 0.647422
# [12]	valid_0's binary_logloss: 0.643929
# [13]	valid_0's binary_logloss: 0.640419
# [14]	valid_0's binary_logloss: 0.636843
# [15]	valid_0's binary_logloss: 0.63336
# [16]	valid_0's binary_logloss: 0.630086
# [17]	valid_0's binary_logloss: 0.626921
# [18]	valid_0's binary_logloss: 0.623635
# [19]	valid_0's binary_logloss: 0.620408
# [20]	valid_0's binary_logloss: 0.617256
# [21]	valid_0's binary_logloss: 0.61423
# [22]	valid_0's binary_logloss: 0.611285
# [23]	valid_0's binary_logloss: 0.608304
# [24]	valid_0's binary_logloss: 0.605434
# [25]	valid_0's binary_logloss: 0.602636
# [26]	valid_0's binary_logloss: 0.599833
# [27]	valid_0's binary_logloss: 0.597073
# [28]	valid_0's binary_logloss: 0.594356
# [29]	valid_0's binary_logloss: 0.5917
# [30]	valid_0's binary_logloss: 0.589094
# [31]	valid_0's binary_logloss: 0.586646
# [32]	valid_0's binary_logloss: 0.584136
# [33]	valid_0's binary_logloss: 0.581684
# [34]	valid_0's binary_logloss: 0.579281
# [35]	valid_0's binary_logloss: 0.576968
# [36]	valid_0's binary_logloss: 0.574738
# [37]	valid_0's binary_logloss: 0.572445
# [38]	valid_0's binary_logloss: 0.570263
# [39]	valid_0's binary_logloss: 0.568043
# [40]	valid_0's binary_logloss: 0.565961
# [41]	valid_0's binary_logloss: 0.563837
# [42]	valid_0's binary_logloss: 0.561812
# [43]	valid_0's binary_logloss: 0.559831
# [44]	valid_0's binary_logloss: 0.557898
# [45]	valid_0's binary_logloss: 0.555934
# [46]	valid_0's binary_logloss: 0.553999
# [47]	valid_0's binary_logloss: 0.552081
# [48]	valid_0's binary_logloss: 0.550215
# [49]	valid_0's binary_logloss: 0.548384
# [50]	valid_0's binary_logloss: 0.546635
# [51]	valid_0's binary_logloss: 0.544854
# [52]	valid_0's binary_logloss: 0.543124
# [53]	valid_0's binary_logloss: 0.541453
# [54]	valid_0's binary_logloss: 0.539758
# [55]	valid_0's binary_logloss: 0.538091
# [56]	valid_0's binary_logloss: 0.5365
# [57]	valid_0's binary_logloss: 0.534887
# [58]	valid_0's binary_logloss: 0.53335
# [59]	valid_0's binary_logloss: 0.531803
# [60]	valid_0's binary_logloss: 0.53035
# [61]	valid_0's binary_logloss: 0.528963
# [62]	valid_0's binary_logloss: 0.527487
# [63]	valid_0's binary_logloss: 0.526038
# [64]	valid_0's binary_logloss: 0.524727
# [65]	valid_0's binary_logloss: 0.523379
# [66]	valid_0's binary_logloss: 0.522084
# [67]	valid_0's binary_logloss: 0.520728
# [68]	valid_0's binary_logloss: 0.519394
# [69]	valid_0's binary_logloss: 0.51813
# [70]	valid_0's binary_logloss: 0.516874
# [71]	valid_0's binary_logloss: 0.515669
# [72]	valid_0's binary_logloss: 0.514454
# [73]	valid_0's binary_logloss: 0.513252
# [74]	valid_0's binary_logloss: 0.512074
# [75]	valid_0's binary_logloss: 0.510909
# [76]	valid_0's binary_logloss: 0.509745
# [77]	valid_0's binary_logloss: 0.508667
# [78]	valid_0's binary_logloss: 0.507592
# [79]	valid_0's binary_logloss: 0.506521
# [80]	valid_0's binary_logloss: 0.50544
# [81]	valid_0's binary_logloss: 0.504442
# [82]	valid_0's binary_logloss: 0.503392
# [83]	valid_0's binary_logloss: 0.502346
# [84]	valid_0's binary_logloss: 0.501323
# [85]	valid_0's binary_logloss: 0.500287
# [86]	valid_0's binary_logloss: 0.499337
# [87]	valid_0's binary_logloss: 0.498318
# [88]	valid_0's binary_logloss: 0.497363
# [89]	valid_0's binary_logloss: 0.496442
# [90]	valid_0's binary_logloss: 0.495494
# [91]	valid_0's binary_logloss: 0.494557
# [92]	valid_0's binary_logloss: 0.493687
# [93]	valid_0's binary_logloss: 0.492768
# [94]	valid_0's binary_logloss: 0.491935
# [95]	valid_0's binary_logloss: 0.491063
# [96]	valid_0's binary_logloss: 0.490189
# [97]	valid_0's binary_logloss: 0.489375
# [98]	valid_0's binary_logloss: 0.488531
# [99]	valid_0's binary_logloss: 0.487757
# [100]	valid_0's binary_logloss: 0.48705
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's binary_logloss: 0.48705
# /opt/conda/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# LGB 6--------------------------------------------------
# [1]	valid_0's binary_logloss: 0.688405
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's binary_logloss: 0.683946
# [3]	valid_0's binary_logloss: 0.67942
# [4]	valid_0's binary_logloss: 0.674983
# [5]	valid_0's binary_logloss: 0.670686
# [6]	valid_0's binary_logloss: 0.666553
# [7]	valid_0's binary_logloss: 0.662586
# [8]	valid_0's binary_logloss: 0.65871
# [9]	valid_0's binary_logloss: 0.65472
# [10]	valid_0's binary_logloss: 0.650992
# [11]	valid_0's binary_logloss: 0.647178
# [12]	valid_0's binary_logloss: 0.64365
# [13]	valid_0's binary_logloss: 0.640132
# [14]	valid_0's binary_logloss: 0.636552
# [15]	valid_0's binary_logloss: 0.633045
# [16]	valid_0's binary_logloss: 0.629747
# [17]	valid_0's binary_logloss: 0.626562
# [18]	valid_0's binary_logloss: 0.623257
# [19]	valid_0's binary_logloss: 0.620022
# [20]	valid_0's binary_logloss: 0.61684
# [21]	valid_0's binary_logloss: 0.613795
# [22]	valid_0's binary_logloss: 0.610834
# [23]	valid_0's binary_logloss: 0.607837
# [24]	valid_0's binary_logloss: 0.604964
# [25]	valid_0's binary_logloss: 0.602154
# [26]	valid_0's binary_logloss: 0.599334
# [27]	valid_0's binary_logloss: 0.596566
# [28]	valid_0's binary_logloss: 0.59384
# [29]	valid_0's binary_logloss: 0.591176
# [30]	valid_0's binary_logloss: 0.588556
# [31]	valid_0's binary_logloss: 0.586105
# [32]	valid_0's binary_logloss: 0.583577
# [33]	valid_0's binary_logloss: 0.581114
# [34]	valid_0's binary_logloss: 0.578693
# [35]	valid_0's binary_logloss: 0.576367
# [36]	valid_0's binary_logloss: 0.574099
# [37]	valid_0's binary_logloss: 0.571792
# [38]	valid_0's binary_logloss: 0.569602
# [39]	valid_0's binary_logloss: 0.567387
# [40]	valid_0's binary_logloss: 0.565297
# [41]	valid_0's binary_logloss: 0.563164
# [42]	valid_0's binary_logloss: 0.56113
# [43]	valid_0's binary_logloss: 0.559133
# [44]	valid_0's binary_logloss: 0.557183
# [45]	valid_0's binary_logloss: 0.555208
# [46]	valid_0's binary_logloss: 0.553262
# [47]	valid_0's binary_logloss: 0.551339
# [48]	valid_0's binary_logloss: 0.549465
# [49]	valid_0's binary_logloss: 0.547625
# [50]	valid_0's binary_logloss: 0.545867
# [51]	valid_0's binary_logloss: 0.544074
# [52]	valid_0's binary_logloss: 0.542333
# [53]	valid_0's binary_logloss: 0.540665
# [54]	valid_0's binary_logloss: 0.538976
# [55]	valid_0's binary_logloss: 0.537299
# [56]	valid_0's binary_logloss: 0.535692
# [57]	valid_0's binary_logloss: 0.534076
# [58]	valid_0's binary_logloss: 0.532523
# [59]	valid_0's binary_logloss: 0.530973
# [60]	valid_0's binary_logloss: 0.529515
# [61]	valid_0's binary_logloss: 0.528114
# [62]	valid_0's binary_logloss: 0.526622
# [63]	valid_0's binary_logloss: 0.525185
# [64]	valid_0's binary_logloss: 0.523865
# [65]	valid_0's binary_logloss: 0.522492
# [66]	valid_0's binary_logloss: 0.521181
# [67]	valid_0's binary_logloss: 0.519816
# [68]	valid_0's binary_logloss: 0.518478
# [69]	valid_0's binary_logloss: 0.517174
# [70]	valid_0's binary_logloss: 0.515913
# [71]	valid_0's binary_logloss: 0.514704
# [72]	valid_0's binary_logloss: 0.513495
# [73]	valid_0's binary_logloss: 0.512289
# [74]	valid_0's binary_logloss: 0.511132
# [75]	valid_0's binary_logloss: 0.509977
# [76]	valid_0's binary_logloss: 0.508818
# [77]	valid_0's binary_logloss: 0.507711
# [78]	valid_0's binary_logloss: 0.506637
# [79]	valid_0's binary_logloss: 0.505562
# [80]	valid_0's binary_logloss: 0.504483
# [81]	valid_0's binary_logloss: 0.503478
# [82]	valid_0's binary_logloss: 0.502432
# [83]	valid_0's binary_logloss: 0.501387
# [84]	valid_0's binary_logloss: 0.500367
# [85]	valid_0's binary_logloss: 0.499348
# [86]	valid_0's binary_logloss: 0.498374
# [87]	valid_0's binary_logloss: 0.497369
# [88]	valid_0's binary_logloss: 0.496421
# [89]	valid_0's binary_logloss: 0.495494
# [90]	valid_0's binary_logloss: 0.49455
# [91]	valid_0's binary_logloss: 0.493623
# [92]	valid_0's binary_logloss: 0.492752
# [93]	valid_0's binary_logloss: 0.49184
# [94]	valid_0's binary_logloss: 0.491004
# [95]	valid_0's binary_logloss: 0.490142
# [96]	valid_0's binary_logloss: 0.48928
# [97]	valid_0's binary_logloss: 0.488463
# [98]	valid_0's binary_logloss: 0.48763
# [99]	valid_0's binary_logloss: 0.486838
# [100]	valid_0's binary_logloss: 0.486127
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's binary_logloss: 0.486127
# /opt/conda/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# LGB 7--------------------------------------------------
# [1]	valid_0's binary_logloss: 0.688419
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's binary_logloss: 0.68397
# [3]	valid_0's binary_logloss: 0.679465
# [4]	valid_0's binary_logloss: 0.675033
# [5]	valid_0's binary_logloss: 0.670741
# [6]	valid_0's binary_logloss: 0.666602
# [7]	valid_0's binary_logloss: 0.662614
# [8]	valid_0's binary_logloss: 0.658741
# [9]	valid_0's binary_logloss: 0.654745
# [10]	valid_0's binary_logloss: 0.650989
# [11]	valid_0's binary_logloss: 0.647177
# [12]	valid_0's binary_logloss: 0.643642
# [13]	valid_0's binary_logloss: 0.640129
# [14]	valid_0's binary_logloss: 0.636545
# [15]	valid_0's binary_logloss: 0.633042
# [16]	valid_0's binary_logloss: 0.629728
# [17]	valid_0's binary_logloss: 0.626544
# [18]	valid_0's binary_logloss: 0.623241
# [19]	valid_0's binary_logloss: 0.620002
# [20]	valid_0's binary_logloss: 0.616833
# [21]	valid_0's binary_logloss: 0.613787
# [22]	valid_0's binary_logloss: 0.610824
# [23]	valid_0's binary_logloss: 0.607841
# [24]	valid_0's binary_logloss: 0.604958
# [25]	valid_0's binary_logloss: 0.602148
# [26]	valid_0's binary_logloss: 0.599318
# [27]	valid_0's binary_logloss: 0.596564
# [28]	valid_0's binary_logloss: 0.593847
# [29]	valid_0's binary_logloss: 0.591199
# [30]	valid_0's binary_logloss: 0.588582
# [31]	valid_0's binary_logloss: 0.586134
# [32]	valid_0's binary_logloss: 0.583602
# [33]	valid_0's binary_logloss: 0.581142
# [34]	valid_0's binary_logloss: 0.578727
# [35]	valid_0's binary_logloss: 0.576401
# [36]	valid_0's binary_logloss: 0.574127
# [37]	valid_0's binary_logloss: 0.571822
# [38]	valid_0's binary_logloss: 0.569627
# [39]	valid_0's binary_logloss: 0.567408
# [40]	valid_0's binary_logloss: 0.565326
# [41]	valid_0's binary_logloss: 0.563183
# [42]	valid_0's binary_logloss: 0.561144
# [43]	valid_0's binary_logloss: 0.559168
# [44]	valid_0's binary_logloss: 0.557223
# [45]	valid_0's binary_logloss: 0.555249
# [46]	valid_0's binary_logloss: 0.553292
# [47]	valid_0's binary_logloss: 0.55136
# [48]	valid_0's binary_logloss: 0.549498
# [49]	valid_0's binary_logloss: 0.54765
# [50]	valid_0's binary_logloss: 0.545882
# [51]	valid_0's binary_logloss: 0.544089
# [52]	valid_0's binary_logloss: 0.542339
# [53]	valid_0's binary_logloss: 0.540668
# [54]	valid_0's binary_logloss: 0.538976
# [55]	valid_0's binary_logloss: 0.537301
# [56]	valid_0's binary_logloss: 0.535698
# [57]	valid_0's binary_logloss: 0.53408
# [58]	valid_0's binary_logloss: 0.532525
# [59]	valid_0's binary_logloss: 0.530977
# [60]	valid_0's binary_logloss: 0.529514
# [61]	valid_0's binary_logloss: 0.528106
# [62]	valid_0's binary_logloss: 0.526611
# [63]	valid_0's binary_logloss: 0.525147
# [64]	valid_0's binary_logloss: 0.523831
# [65]	valid_0's binary_logloss: 0.522466
# [66]	valid_0's binary_logloss: 0.521162
# [67]	valid_0's binary_logloss: 0.519793
# [68]	valid_0's binary_logloss: 0.518448
# [69]	valid_0's binary_logloss: 0.517169
# [70]	valid_0's binary_logloss: 0.515905
# [71]	valid_0's binary_logloss: 0.514686
# [72]	valid_0's binary_logloss: 0.513482
# [73]	valid_0's binary_logloss: 0.51227
# [74]	valid_0's binary_logloss: 0.511087
# [75]	valid_0's binary_logloss: 0.509934
# [76]	valid_0's binary_logloss: 0.508758
# [77]	valid_0's binary_logloss: 0.507668
# [78]	valid_0's binary_logloss: 0.506573
# [79]	valid_0's binary_logloss: 0.505512
# [80]	valid_0's binary_logloss: 0.504427
# [81]	valid_0's binary_logloss: 0.50342
# [82]	valid_0's binary_logloss: 0.502366
# [83]	valid_0's binary_logloss: 0.501318
# [84]	valid_0's binary_logloss: 0.500283
# [85]	valid_0's binary_logloss: 0.499265
# [86]	valid_0's binary_logloss: 0.498292
# [87]	valid_0's binary_logloss: 0.497284
# [88]	valid_0's binary_logloss: 0.496337
# [89]	valid_0's binary_logloss: 0.495412
# [90]	valid_0's binary_logloss: 0.494475
# [91]	valid_0's binary_logloss: 0.493559
# [92]	valid_0's binary_logloss: 0.492682
# [93]	valid_0's binary_logloss: 0.491757
# [94]	valid_0's binary_logloss: 0.490922
# [95]	valid_0's binary_logloss: 0.490048
# [96]	valid_0's binary_logloss: 0.489171
# [97]	valid_0's binary_logloss: 0.488363
# [98]	valid_0's binary_logloss: 0.487514
# [99]	valid_0's binary_logloss: 0.486727
# [100]	valid_0's binary_logloss: 0.48601
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's binary_logloss: 0.48601
# /opt/conda/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# LGB 8--------------------------------------------------
# [1]	valid_0's binary_logloss: 0.68841
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's binary_logloss: 0.683986
# [3]	valid_0's binary_logloss: 0.679474
# [4]	valid_0's binary_logloss: 0.675045
# [5]	valid_0's binary_logloss: 0.670735
# [6]	valid_0's binary_logloss: 0.666592
# [7]	valid_0's binary_logloss: 0.662621
# [8]	valid_0's binary_logloss: 0.658741
# [9]	valid_0's binary_logloss: 0.654744
# [10]	valid_0's binary_logloss: 0.651007
# [11]	valid_0's binary_logloss: 0.647192
# [12]	valid_0's binary_logloss: 0.643685
# [13]	valid_0's binary_logloss: 0.640163
# [14]	valid_0's binary_logloss: 0.636574
# [15]	valid_0's binary_logloss: 0.633071
# [16]	valid_0's binary_logloss: 0.629775
# [17]	valid_0's binary_logloss: 0.626588
# [18]	valid_0's binary_logloss: 0.623285
# [19]	valid_0's binary_logloss: 0.620052
# [20]	valid_0's binary_logloss: 0.616885
# [21]	valid_0's binary_logloss: 0.613837
# [22]	valid_0's binary_logloss: 0.610871
# [23]	valid_0's binary_logloss: 0.607873
# [24]	valid_0's binary_logloss: 0.604992
# [25]	valid_0's binary_logloss: 0.602177
# [26]	valid_0's binary_logloss: 0.599358
# [27]	valid_0's binary_logloss: 0.596603
# [28]	valid_0's binary_logloss: 0.593884
# [29]	valid_0's binary_logloss: 0.591233
# [30]	valid_0's binary_logloss: 0.588621
# [31]	valid_0's binary_logloss: 0.586174
# [32]	valid_0's binary_logloss: 0.583657
# [33]	valid_0's binary_logloss: 0.581207
# [34]	valid_0's binary_logloss: 0.578838
# [35]	valid_0's binary_logloss: 0.576511
# [36]	valid_0's binary_logloss: 0.574264
# [37]	valid_0's binary_logloss: 0.571965
# [38]	valid_0's binary_logloss: 0.569768
# [39]	valid_0's binary_logloss: 0.567543
# [40]	valid_0's binary_logloss: 0.565454
# [41]	valid_0's binary_logloss: 0.563314
# [42]	valid_0's binary_logloss: 0.561277
# [43]	valid_0's binary_logloss: 0.559303
# [44]	valid_0's binary_logloss: 0.557348
# [45]	valid_0's binary_logloss: 0.555371
# [46]	valid_0's binary_logloss: 0.553419
# [47]	valid_0's binary_logloss: 0.551495
# [48]	valid_0's binary_logloss: 0.549621
# [49]	valid_0's binary_logloss: 0.54778
# [50]	valid_0's binary_logloss: 0.546011
# [51]	valid_0's binary_logloss: 0.544223
# [52]	valid_0's binary_logloss: 0.54248
# [53]	valid_0's binary_logloss: 0.540817
# [54]	valid_0's binary_logloss: 0.53912
# [55]	valid_0's binary_logloss: 0.537443
# [56]	valid_0's binary_logloss: 0.535844
# [57]	valid_0's binary_logloss: 0.534228
# [58]	valid_0's binary_logloss: 0.532679
# [59]	valid_0's binary_logloss: 0.531129
# [60]	valid_0's binary_logloss: 0.529681
# [61]	valid_0's binary_logloss: 0.528285
# [62]	valid_0's binary_logloss: 0.52681
# [63]	valid_0's binary_logloss: 0.525365
# [64]	valid_0's binary_logloss: 0.52403
# [65]	valid_0's binary_logloss: 0.522671
# [66]	valid_0's binary_logloss: 0.521373
# [67]	valid_0's binary_logloss: 0.520002
# [68]	valid_0's binary_logloss: 0.518657
# [69]	valid_0's binary_logloss: 0.517383
# [70]	valid_0's binary_logloss: 0.51613
# [71]	valid_0's binary_logloss: 0.514921
# [72]	valid_0's binary_logloss: 0.513709
# [73]	valid_0's binary_logloss: 0.5125
# [74]	valid_0's binary_logloss: 0.511337
# [75]	valid_0's binary_logloss: 0.510172
# [76]	valid_0's binary_logloss: 0.509002
# [77]	valid_0's binary_logloss: 0.507906
# [78]	valid_0's binary_logloss: 0.506822
# [79]	valid_0's binary_logloss: 0.505771
# [80]	valid_0's binary_logloss: 0.504704
# [81]	valid_0's binary_logloss: 0.503704
# [82]	valid_0's binary_logloss: 0.502659
# [83]	valid_0's binary_logloss: 0.501607
# [84]	valid_0's binary_logloss: 0.500579
# [85]	valid_0's binary_logloss: 0.499556
# [86]	valid_0's binary_logloss: 0.498575
# [87]	valid_0's binary_logloss: 0.497561
# [88]	valid_0's binary_logloss: 0.496616
# [89]	valid_0's binary_logloss: 0.495699
# [90]	valid_0's binary_logloss: 0.494757
# [91]	valid_0's binary_logloss: 0.493839
# [92]	valid_0's binary_logloss: 0.49297
# [93]	valid_0's binary_logloss: 0.492058
# [94]	valid_0's binary_logloss: 0.491223
# [95]	valid_0's binary_logloss: 0.490352
# [96]	valid_0's binary_logloss: 0.489489
# [97]	valid_0's binary_logloss: 0.488667
# [98]	valid_0's binary_logloss: 0.487831
# [99]	valid_0's binary_logloss: 0.487046
# [100]	valid_0's binary_logloss: 0.486326
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's binary_logloss: 0.486326
# /opt/conda/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# LGB 9--------------------------------------------------
# [1]	valid_0's binary_logloss: 0.688439
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's binary_logloss: 0.684044
# [3]	valid_0's binary_logloss: 0.679552
# [4]	valid_0's binary_logloss: 0.675145
# [5]	valid_0's binary_logloss: 0.670871
# [6]	valid_0's binary_logloss: 0.666761
# [7]	valid_0's binary_logloss: 0.66282
# [8]	valid_0's binary_logloss: 0.658977
# [9]	valid_0's binary_logloss: 0.655005
# [10]	valid_0's binary_logloss: 0.651297
# [11]	valid_0's binary_logloss: 0.647501
# [12]	valid_0's binary_logloss: 0.64401
# [13]	valid_0's binary_logloss: 0.640516
# [14]	valid_0's binary_logloss: 0.636949
# [15]	valid_0's binary_logloss: 0.633471
# [16]	valid_0's binary_logloss: 0.630191
# [17]	valid_0's binary_logloss: 0.627016
# [18]	valid_0's binary_logloss: 0.623728
# [19]	valid_0's binary_logloss: 0.620508
# [20]	valid_0's binary_logloss: 0.617373
# [21]	valid_0's binary_logloss: 0.614344
# [22]	valid_0's binary_logloss: 0.611403
# [23]	valid_0's binary_logloss: 0.608429
# [24]	valid_0's binary_logloss: 0.605564
# [25]	valid_0's binary_logloss: 0.602773
# [26]	valid_0's binary_logloss: 0.59997
# [27]	valid_0's binary_logloss: 0.597224
# [28]	valid_0's binary_logloss: 0.594511
# [29]	valid_0's binary_logloss: 0.591861
# [30]	valid_0's binary_logloss: 0.589256
# [31]	valid_0's binary_logloss: 0.58683
# [32]	valid_0's binary_logloss: 0.584321
# [33]	valid_0's binary_logloss: 0.581881
# [34]	valid_0's binary_logloss: 0.579488
# [35]	valid_0's binary_logloss: 0.577177
# [36]	valid_0's binary_logloss: 0.574964
# [37]	valid_0's binary_logloss: 0.572688
# [38]	valid_0's binary_logloss: 0.57051
# [39]	valid_0's binary_logloss: 0.568304
# [40]	valid_0's binary_logloss: 0.566232
# [41]	valid_0's binary_logloss: 0.564104
# [42]	valid_0's binary_logloss: 0.562086
# [43]	valid_0's binary_logloss: 0.560123
# [44]	valid_0's binary_logloss: 0.558188
# [45]	valid_0's binary_logloss: 0.556226
# [46]	valid_0's binary_logloss: 0.554287
# [47]	valid_0's binary_logloss: 0.552375
# [48]	valid_0's binary_logloss: 0.550527
# [49]	valid_0's binary_logloss: 0.548699
# [50]	valid_0's binary_logloss: 0.546969
# [51]	valid_0's binary_logloss: 0.5452
# [52]	valid_0's binary_logloss: 0.543469
# [53]	valid_0's binary_logloss: 0.541812
# [54]	valid_0's binary_logloss: 0.540127
# [55]	valid_0's binary_logloss: 0.538467
# [56]	valid_0's binary_logloss: 0.536866
# [57]	valid_0's binary_logloss: 0.535256
# [58]	valid_0's binary_logloss: 0.533709
# [59]	valid_0's binary_logloss: 0.53217
# [60]	valid_0's binary_logloss: 0.530712
# [61]	valid_0's binary_logloss: 0.529329
# [62]	valid_0's binary_logloss: 0.527851
# [63]	valid_0's binary_logloss: 0.526405
# [64]	valid_0's binary_logloss: 0.525089
# [65]	valid_0's binary_logloss: 0.523737
# [66]	valid_0's binary_logloss: 0.522449
# [67]	valid_0's binary_logloss: 0.5211
# [68]	valid_0's binary_logloss: 0.519779
# [69]	valid_0's binary_logloss: 0.518505
# [70]	valid_0's binary_logloss: 0.517249
# [71]	valid_0's binary_logloss: 0.516047
# [72]	valid_0's binary_logloss: 0.514844
# [73]	valid_0's binary_logloss: 0.513642
# [74]	valid_0's binary_logloss: 0.51248
# [75]	valid_0's binary_logloss: 0.511333
# [76]	valid_0's binary_logloss: 0.510177
# [77]	valid_0's binary_logloss: 0.509087
# [78]	valid_0's binary_logloss: 0.508017
# [79]	valid_0's binary_logloss: 0.506976
# [80]	valid_0's binary_logloss: 0.505908
# [81]	valid_0's binary_logloss: 0.504913
# [82]	valid_0's binary_logloss: 0.503865
# [83]	valid_0's binary_logloss: 0.502826
# [84]	valid_0's binary_logloss: 0.501812
# [85]	valid_0's binary_logloss: 0.50081
# [86]	valid_0's binary_logloss: 0.499844
# [87]	valid_0's binary_logloss: 0.498862
# [88]	valid_0's binary_logloss: 0.49792
# [89]	valid_0's binary_logloss: 0.497009
# [90]	valid_0's binary_logloss: 0.496065
# [91]	valid_0's binary_logloss: 0.495157
# [92]	valid_0's binary_logloss: 0.494291
# [93]	valid_0's binary_logloss: 0.493385
# [94]	valid_0's binary_logloss: 0.492554
# [95]	valid_0's binary_logloss: 0.491704
# [96]	valid_0's binary_logloss: 0.490859
# [97]	valid_0's binary_logloss: 0.490045
# [98]	valid_0's binary_logloss: 0.489203
# [99]	valid_0's binary_logloss: 0.488428
# [100]	valid_0's binary_logloss: 0.487708
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's binary_logloss: 0.487708
# /opt/conda/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %% [markdown]
# This predicts a numerical value whether an user will buy from the GStore or not.

# %%
ypred = clf.predict(X, num_iteration=clf.best_iteration_)
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %% [markdown]
# Converting the numerically predictied values into softmax scores.

# %%
def softmax(X, theta = 1.0, axis = None):

    y = np.atleast_2d(X)


    if axis is None:
        axis = next(j[0] for j in enumerate(y.shape) if j[1] > 1)

    y = y * float(theta)

    y = y - np.expand_dims(np.max(y, axis = axis), axis)

    y = np.exp(y)

    ax_sum = np.expand_dims(np.sum(y, axis = axis), axis)

    p = y / ax_sum

    if len(X.shape) == 1: p = p.flatten()

    return p

# %%
yproba = clf.predict_proba(X, clf.best_iteration_)
yproba = softmax(yproba, axis = 1)
buyprob = yproba[:,1]

toptenbuyers = []
for i in range(10):
    top = buyprob.argmax()
    toptenbuyers.append(top)
    buyprob[top] = 0
buyers = []
for i in toptenbuyers:
    buyers.append(tmp_probdf.loc[i,'fullVisitorId'])

# %% [markdown]
# printing the sorted values of buyers

# %%
buyers
# Out:
# ['8946514554986669717',
#  '700225401855286769',
#  '4064008221273566105',
#  '4064008221273566105',
#  '3980601042365877663',
#  '3087800167641443127',
#  '6180179196714828509',
#  '8518736572243003083',
#  '7048142789651941273',
#  '5179586107192059934',
#  '7308095176976751222',
#  '8652691250363359598',
#  '2752688798072608210']

# %%
newX = pd.read_csv("../input/kernel-for-data/train-flat.csv", low_memory = False)
tmp = pd.DataFrame()

# %%
for i in buyers: 
    tmp = pd.concat([tmp,newX[newX['fullVisitorId'] == i]])

# %% [markdown]
# Below are further details of the buyers according their fullvisitor ID

# %%
tmp
# Out:
#        channelGrouping          ...           trafficSource.source
# 3353          Referral          ...            mall.googleplex.com
# 613649        Referral          ...            mall.googleplex.com
# 3391          Referral          ...            mall.googleplex.com
# 6671          Referral          ...            mall.googleplex.com
# 6755          Referral          ...            mall.googleplex.com
# 572558        Referral          ...            mall.googleplex.com
# 6671          Referral          ...            mall.googleplex.com
# 6755          Referral          ...            mall.googleplex.com
# 572558        Referral          ...            mall.googleplex.com
# 8245          Referral          ...            mall.googleplex.com
# 318946        Referral          ...            mall.googleplex.com
# 319307        Referral          ...            mall.googleplex.com
# 10473         Referral          ...            mall.googleplex.com
# 11287         Referral          ...            mall.googleplex.com
# 11356         Referral          ...                mail.google.com
# 122867  Organic Search          ...                         google
# 538354        Referral          ...                mail.google.com
# 538743          Direct          ...                       (direct)
# 767252        Referral          ...                mail.google.com
# 767424  Organic Search          ...                         google
# 767887  Organic Search          ...                         google
# 767913  Organic Search          ...                         google
# 14197         Referral          ...            mall.googleplex.com
# 14247         Referral          ...            mall.googleplex.com
# 451060        Referral          ...            mall.googleplex.com
# 754422        Referral          ...            mall.googleplex.com
# 16830           Direct          ...                       (direct)
# 17232         Referral          ...            mall.googleplex.com
# 30808         Referral          ...            mall.googleplex.com
# 35852         Referral          ...            mall.googleplex.com
# 120117        Referral          ...            mall.googleplex.com
# 172344        Referral          ...            mall.googleplex.com
# 203241  Organic Search          ...                         google
# 567584  Organic Search          ...                         google
# 624881        Referral          ...            mall.googleplex.com
# 625528  Organic Search          ...                         google
# 733593        Referral          ...            mall.googleplex.com
# 30803         Referral          ...            mall.googleplex.com
# 30865         Referral          ...            mall.googleplex.com
# 30879         Referral          ...            mall.googleplex.com
# 149551        Referral          ...            mall.googleplex.com
# 150637        Referral          ...            mall.googleplex.com
# 275348        Referral          ...            mall.googleplex.com
# 275471        Referral          ...            mall.googleplex.com
# 698679        Referral          ...            mall.googleplex.com
# 32889         Referral          ...            mall.googleplex.com
# 32890         Referral          ...            mall.googleplex.com
# 164822        Referral          ...            mall.googleplex.com
# 225165        Referral          ...            mall.googleplex.com
#
# [49 rows x 55 columns]

# %%
X_train.head()
# Out:
#    channelGrouping     ...      buyornobuy
# 0                4     ...             0.0
# 1                4     ...             0.0
# 2                4     ...             0.0
# 3                4     ...             0.0
# 4                4     ...             0.0
#
# [5 rows x 27 columns]

# %% [markdown]
# Prepping the data for training, encoding labels to all values appended in the categorical column

# %%
from sklearn.preprocessing import LabelEncoder
for col in categorical:
    lbl = LabelEncoder()
    df_all[col] = lbl.fit_transform(df_all[col])

# %%
df_all.head()
# Out:
#    channelGrouping  day  ...   weekOfTheYear  year
# 0                4    4  ...              34     0
# 1                4    4  ...              34     0
# 2                4    4  ...              34     0
# 3                4    4  ...              34     0
# 4                4    4  ...              34     0
#
# [5 rows x 28 columns]

# %%
X_train = df_all[:len_Xtrain]
X_test = df_all[len_Xtrain:]

# %%
X_train.head()
# Out:
#    channelGrouping  day  ...   weekOfTheYear  year
# 0                4    4  ...              34     0
# 1                4    4  ...              34     0
# 2                4    4  ...              34     0
# 3                4    4  ...              34     0
# 4                4    4  ...              34     0
#
# [5 rows x 28 columns]

# %%
X_train_fullVisitorId = X_train['fullVisitorId']
X_train_sessionId = X_train['sessionId']
X_train_visitId = X_train['visitId']

# %%
X_test_fullVisitorId = X_test['fullVisitorId']
X_test_sessionId = X_test['sessionId']
X_test_visitId = X_test['visitId']

# %%
X_train.drop(['fullVisitorId', 'sessionId', 'visitId'], axis=1, inplace=True)
X_test.drop(['fullVisitorId', 'sessionId', 'visitId'], axis=1, inplace=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
list(X_train.columns)

# %%
tmp = []
not_col = ['fullVisitorId','sessionId','visitId']
for col in X_train.columns:
    if col not in not_col:
        tmp.append(col)

# %% [markdown]
# Computing the Pscore

# %%
from sklearn.feature_selection import f_regression
X = X_train.loc[:, tmp]
F, pval = f_regression(X=X, y = Y_train)

# %%
plt.figure(figsize = (10,5))
plt.plot(tmp,pval)
plt.xticks(rotation=90)
plt.show()

# %%
categorical

# %% [markdown]
# Model training

# %%
params = {
        "objective" : "regression",
        "metric" : "rmse", 
        "num_leaves" : 30,
        "min_child_samples" : 100,
        "learning_rate" : 0.1,
        "bagging_fraction" : 0.7,
        "feature_fraction" : 0.5,
        "bagging_frequency" : 5,
        "bagging_seed" : 1989,
        "verbosity" : -1,
        'seed': 1989
    }

# %%
from sklearn.model_selection import KFold
import time
import lightgbm as lgb

folds = KFold(n_splits=5, shuffle=True, random_state=15)
oof = np.zeros(len(X_train))
predictions = np.zeros(len(X_test))
start = time.time()
features = list(X_train.columns)
feature_importance_df = pd.DataFrame()

# %%
X_train.head()
# Out:
#    channelGrouping  day  ...   weekOfTheYear  year
# 0                4    4  ...              34     0
# 1                4    4  ...              34     0
# 2                4    4  ...              34     0
# 3                4    4  ...              34     0
# 4                4    4  ...              34     0
#
# [5 rows x 25 columns]

# %%
for fold_, (trn_idx, val_idx) in enumerate(folds.split(X_train.values, Y_train.values)):
    trn_data = lgb.Dataset(X_train.iloc[trn_idx], label=Y_train.iloc[trn_idx], categorical_feature=categorical)
    val_data = lgb.Dataset(X_train.iloc[val_idx], label=Y_train.iloc[val_idx], categorical_feature=categorical)
    
    num_round = 10000
    clf = lgb.train(params, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=400, early_stopping_rounds = 500, categorical_feature=categorical)
    oof[val_idx] = clf.predict(X_train.iloc[val_idx].values, num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["feature"] = features
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(X_test.values, num_iteration=clf.best_iteration) / folds.n_splits
# Out:
# /opt/conda/lib/python3.6/site-packages/lightgbm/basic.py:742: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# Training until validation scores don't improve for 500 rounds.
# [400]	training's rmse: 1.42733	valid_1's rmse: 1.61321
# Early stopping, best iteration is:
# [146]	training's rmse: 1.50506	valid_1's rmse: 1.60647
# Training until validation scores don't improve for 500 rounds.
# [400]	training's rmse: 1.41999	valid_1's rmse: 1.61383
# Early stopping, best iteration is:
# [119]	training's rmse: 1.51056	valid_1's rmse: 1.60702
# Training until validation scores don't improve for 500 rounds.
# [400]	training's rmse: 1.4241	valid_1's rmse: 1.61938
# Early stopping, best iteration is:
# [145]	training's rmse: 1.50258	valid_1's rmse: 1.6125
# Training until validation scores don't improve for 500 rounds.
# [400]	training's rmse: 1.41826	valid_1's rmse: 1.63415
# Early stopping, best iteration is:
# [128]	training's rmse: 1.50389	valid_1's rmse: 1.62541
# Training until validation scores don't improve for 500 rounds.
# [400]	training's rmse: 1.42652	valid_1's rmse: 1.60616
# Early stopping, best iteration is:
# [119]	training's rmse: 1.51691	valid_1's rmse: 1.59678

# %%
submission = pd.DataFrame()

submission['fullVisitorId'] = X_test_fullVisitorId

submission['PredictedLogRevenue'] = predictions

grouped_test = submission[['fullVisitorId', 'PredictedLogRevenue']].groupby('fullVisitorId').sum().reset_index()
grouped_test.to_csv('submit.csv',index=False)

# %% [markdown]
# Referenced the following kernel
# https://www.kaggle.com/youhanlee/eda-lgbm-for-starter-lb-1-6878
